# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import joblib
import time
import re
import warnings
from tabulate import tabulate
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_validate, cross_val_predict
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from IPython.display import display
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import cross_val_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv('gym_recommendation_modified_scientific3.csv')
print(f"Shape: {df.shape}")
# Out:
# Shape: (14589, 15)

# %%
print("Info Data Awal:")
df.info()
# Out:
# Info Data Awal:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14589 entries, 0 to 14588
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              14589 non-null  int64
#  1   Sex             14589 non-null  object
#  2   Age             14589 non-null  int64
#  3   Height          14589 non-null  float64
#  4   Weight          14589 non-null  float64
#  5   Hypertension    14589 non-null  object
#  6   Diabetes        14589 non-null  object
#  7   BMI             14589 non-null  float64
#  8   Level           14589 non-null  object
#  9   Fitness Goal    14589 non-null  object
#  10  Fitness Type    14589 non-null  object
#  11  Exercises       14589 non-null  object
#  12  Equipment       14589 non-null  object
#  13  Diet            14589 non-null  object
#  14  Recommendation  14589 non-null  object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 1.7+ MB

# %%
print("\nDescribe Data Awal:")
print(df.describe())
# Out:
# Describe Data Awal:
#                  ID           Age        Height        Weight           BMI
# count  14589.000000  14589.000000  14589.000000  14589.000000  14589.000000
# mean    7295.000000     39.554870      1.699851     70.505991     24.417569
# std     4211.625874     13.192655      0.098129     20.030635      6.765144
# min        1.000000     18.000000      1.300000     32.000000      9.520000
# 25%     3648.000000     28.000000      1.640000     55.000000     18.940000
# 50%     7295.000000     39.000000      1.680000     70.000000     25.250000
# 75%    10942.000000     51.000000      1.770000     86.000000     29.320000
# max    14589.000000     63.000000      2.030000    130.000000     70.000000

# %%
print(f"\nJumlah Null:\n{df.isnull().sum()}")
print(f"\nJumlah Duplikat: {df.duplicated().sum()}")
# Out:
# Jumlah Null:
# ID                0
# Sex               0
# Age               0
# Height            0
# Weight            0
# Hypertension      0
# Diabetes          0
# BMI               0
# Level             0
# Fitness Goal      0
# Fitness Type      0
# Exercises         0
# Equipment         0
# Diet              0
# Recommendation    0
# dtype: int64
#
# Jumlah Duplikat: 0

# %%
print("\nHead Data Awal:")
print(df.head())
# Out:
# Head Data Awal:
#    ID   Sex  Age  Height  Weight Hypertension Diabetes    BMI        Level  \
# 0   1  Male   18    1.68    47.5           No       No  16.83  Underweight
# 1   2  Male   18    1.68    47.5          Yes       No  16.83  Underweight
# 2   3  Male   18    1.68    47.5           No      Yes  16.83  Underweight
# 3   4  Male   18    1.68    47.5          Yes      Yes  16.83  Underweight
# 4   5  Male   18    1.68    47.5           No       No  16.83  Underweight
#
#   Fitness Goal      Fitness Type  \
# 0  Weight Gain  Muscular Fitness
# 1  Weight Loss    Cardio Fitness
# 2  Weight Gain  Muscular Fitness
# 3  Weight Gain  Muscular Fitness
# 4  Weight Gain  Muscular Fitness
#
#                                            Exercises  \
# 0  Squats, deadlifts, bench presses, and overhead...
# 1  Squats, deadlifts, bench presses, and overhead...
# 2  Squats, yoga, deadlifts, bench presses, and ov...
# 3  Squats, yoga, cycling, dumbbell), Dumbbell ben...
# 4  Squats, deadlifts, bench presses, and overhead...
#
#                                            Equipment  \
# 0  Dumbbells and barbells, Dumbbell, Flat bench, ...
# 1  Light athletic shoes, resistance bands, and li...
# 2  Dumbbells, barbells and Blood glucose monitor,...
# 3  Light athletic shoes, resistance bands, light ...
# 4  Dumbbells and barbells, Dumbbell, Flat bench, ...
#
#                                                 Diet  \
# 0  Vegetables: (Carrots, Sweet Potato, and Lettuc...
# 1  Vegetables: (Tomatoes, Garlic, leafy greens, b...
# 2  Vegetables: (Garlic, Roma Tomatoes, Capers and...
# 3  Vegetables: (Garlic, Roma Tomatoes, Capers, Gr...
# 4  Vegetables: (Carrots, Sweet Potato, Lettuce); ...
#
#                                       Recommendation
# 0  Follow a regular exercise schedule. Adhere to ...
# 1  Follow a regular exercise schedule. Adhere to ...
# 2  Follow a regular exercise schedule. Adhere to ...
# 3  Follow a regular exercise schedule. Adhere to ...
# 4  Follow a regular exercise schedule. Adhere to ...

# %% [markdown]
# ## Preprocessing Data

# %%
print("\nMemulai cleaning data awal")
initial_rows = len(df)
df.drop_duplicates(inplace=True)
if len(df) < initial_rows:
  print(f"- Menghapus {initial_rows - len(df)} baris duplikat.")

if 'Obuse' in df['Level'].unique():
  df['Level'] = df['Level'].replace('Obuse', 'Obese')
  print("- Mengganti 'Obuse' menjadi 'Obese'.")

if df['Height'].max() < 10:
  df['Height'] = df['Height'] * 100
  print("- Mengkonversi 'Height' ke cm.")
else:
  print("- Kolom 'Height' sudah dalam cm.")

def get_age_group(age):
    if 18 <= age <= 25: return "18-25"
    elif 26 <= age <= 35: return "26-35"
    elif 36 <= age <= 45: return "36-45"
    elif 46 <= age <= 55: return "46-55"
    else: return "56+"

print("- Membuat kolom 'Age Group' baru.")
df['Age Group'] = df['Age'].apply(get_age_group)

print("\nCleaning data awal selesai.")
print("\nContoh data setelah cleaning awal:")
print(df.head())
# Out:
# Memulai cleaning data awal
# - Mengganti 'Obuse' menjadi 'Obese'.
# - Mengkonversi 'Height' ke cm.
# - Membuat kolom 'Age Group' baru.
#
# Cleaning data awal selesai.
#
# Contoh data setelah cleaning awal:
#    ID   Sex  Age  Height  Weight Hypertension Diabetes    BMI        Level  \
# 0   1  Male   18   168.0    47.5           No       No  16.83  Underweight
# 1   2  Male   18   168.0    47.5          Yes       No  16.83  Underweight
# 2   3  Male   18   168.0    47.5           No      Yes  16.83  Underweight
# 3   4  Male   18   168.0    47.5          Yes      Yes  16.83  Underweight
# 4   5  Male   18   168.0    47.5           No       No  16.83  Underweight
#
#   Fitness Goal      Fitness Type  \
# 0  Weight Gain  Muscular Fitness
# 1  Weight Loss    Cardio Fitness
# 2  Weight Gain  Muscular Fitness
# 3  Weight Gain  Muscular Fitness
# 4  Weight Gain  Muscular Fitness
#
#                                            Exercises  \
# 0  Squats, deadlifts, bench presses, and overhead...
# 1  Squats, deadlifts, bench presses, and overhead...
# 2  Squats, yoga, deadlifts, bench presses, and ov...
# 3  Squats, yoga, cycling, dumbbell), Dumbbell ben...
# 4  Squats, deadlifts, bench presses, and overhead...
#
#                                            Equipment  \
# 0  Dumbbells and barbells, Dumbbell, Flat bench, ...
# 1  Light athletic shoes, resistance bands, and li...
# 2  Dumbbells, barbells and Blood glucose monitor,...
# 3  Light athletic shoes, resistance bands, light ...
# 4  Dumbbells and barbells, Dumbbell, Flat bench, ...
#
#                                                 Diet  \
# 0  Vegetables: (Carrots, Sweet Potato, and Lettuc...
# 1  Vegetables: (Tomatoes, Garlic, leafy greens, b...
# 2  Vegetables: (Garlic, Roma Tomatoes, Capers and...
# 3  Vegetables: (Garlic, Roma Tomatoes, Capers, Gr...
# 4  Vegetables: (Carrots, Sweet Potato, Lettuce); ...
#
#                                       Recommendation Age Group
# 0  Follow a regular exercise schedule. Adhere to ...     18-25
# 1  Follow a regular exercise schedule. Adhere to ...     18-25
# 2  Follow a regular exercise schedule. Adhere to ...     18-25
# 3  Follow a regular exercise schedule. Adhere to ...     18-25
# 4  Follow a regular exercise schedule. Adhere to ...     18-25

# %% [markdown]
# # Persiapan Data KNN

# %%
# Tentukan prediktor dan target
features = ['Sex', 'Age', 'Height', 'Weight', 'BMI', 'Level', 'Fitness Goal', 'Age Group']
X = df[features].copy()
y = df['Fitness Type']

# Encoding Data Kategorical
categorical_cols = ['Sex', 'Level', 'Fitness Goal', 'Age Group']
le_dict = {}
print("Encoding fitur kategorikal:", categorical_cols)

for col in categorical_cols:
    le = LabelEncoder()
    X.loc[:, col] = le.fit_transform(X[col].astype(str))
    le_dict[col] = le

# Encoding Target
le_target = LabelEncoder()
y_encoded = le_target.fit_transform(y.astype(str)) # Pake variable baru biar aman
print(f"\nEncoding target 'Fitness Type'. Kelas: {le_target.classes_}")
# Out:
# Encoding fitur kategorikal: ['Sex', 'Level', 'Fitness Goal', 'Age Group']
#
# Encoding target 'Fitness Type'. Kelas: ['Cardio Fitness' 'Muscular Fitness']

# %%
# Data splitting 80:20
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded
)

print(f"Total Data: {len(X)}")
print(f"Data Latih: {len(X_train)} baris (80%)")
print(f"Data Uji: {len(X_test)} baris (20%)")
# Out:
# Total Data: 14589
# Data Latih: 11671 baris (80%)
# Data Uji: 2918 baris (20%)

# %%
# Scaling
numeric_cols = ['Age', 'Height', 'Weight', 'BMI']
scaler = StandardScaler()

X_train_scaled = X_train.copy()
X_train_scaled[numeric_cols] = scaler.fit_transform(X_train[numeric_cols])

X_test_scaled = X_test.copy()
X_test_scaled[numeric_cols] = scaler.transform(X_test[numeric_cols])

# %% [markdown]
# # Training dan Evaluasi Model KNN

# %%
# Parameter (k) jarak KNN
k_values = [3, 5, 7]
scoring_metrics = ['accuracy', 'precision_weighted', 'recall_weighted', 'f1_weighted']

for k in k_values:
    print(f"\n KNN Parameter k = {k} (Evaluasi pada Data Latih 80%)")

    knn = KNeighborsClassifier(n_neighbors=k)

    results = cross_validate(knn, X_train_scaled, y_train, cv=10, scoring=scoring_metrics)

    data = {
        'Eksperimen (Fold)': list(range(1, 11)),
        'Akurasi': results['test_accuracy'],
        'Precision': results['test_precision_weighted'],
        'Recall': results['test_recall_weighted'],
        'F1 Score': results['test_f1_weighted']
    }

    df_results = pd.DataFrame(data)

    mean_row = {
        'Eksperimen (Fold)': 'Rata-rata',
        'Akurasi': df_results['Akurasi'].mean(),
        'Precision': df_results['Precision'].mean(),
        'Recall': df_results['Recall'].mean(),
        'F1 Score': df_results['F1 Score'].mean()
    }

    df_final = pd.concat([df_results, pd.DataFrame([mean_row])], ignore_index=True)
    cols_to_format = ['Akurasi', 'Precision', 'Recall', 'F1 Score']

    print(f"Tabel Evaluasi 10-Fold CV pada Data Latih (k={k}):")
    display(df_final.style.format(subset=cols_to_format, formatter="{:.4f}").hide(axis='index'))

    # Confusion Matrix
    y_pred_cv = cross_val_predict(knn, X_train_scaled, y_train, cv=10)

    cm = confusion_matrix(y_train, y_pred_cv)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=le_target.classes_)

    fig, ax = plt.subplots(figsize=(8, 6))
    disp.plot(cmap='Blues', ax=ax)
    plt.title(f'Confusion Matrix KNN (k={k}) - Split Data 80:20', fontsize=14)
    plt.show()

    print("\n")
# Out:
# ========================= KNN Parameter k = 3 (Evaluasi pada Data Latih 80%) =========================
# Tabel Evaluasi 10-Fold CV pada Data Latih (k=3):
# <style type="text/css">
# </style>
# <table id="T_9b211" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_9b211_level0_col0" class="col_heading level0 col0" >Eksperimen (Fold)</th>
#       <th id="T_9b211_level0_col1" class="col_heading level0 col1" >Akurasi</th>
#       <th id="T_9b211_level0_col2" class="col_heading level0 col2" >Precision</th>
#       <th id="T_9b211_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_9b211_level0_col4" class="col_heading level0 col4" >F1 Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9b211_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_9b211_row0_col1" class="data row0 col1" >0.9409</td>
#       <td id="T_9b211_row0_col2" class="data row0 col2" >0.9423</td>
#       <td id="T_9b211_row0_col3" class="data row0 col3" >0.9409</td>
#       <td id="T_9b211_row0_col4" class="data row0 col4" >0.9403</td>
#     </tr>
#     <tr>
#       <td id="T_9b211_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_9b211_row1_col1" class="data row1 col1" >0.9366</td>
#       <td id="T_9b211_row1_col2" class="data row1 col2" >0.9370</td>
#       <td id="T_9b211_row1_col3" class="data row1 col3" >0.9366</td>
#       <td id="T_9b211_row1_col4" class="data row1 col4" >0.9361</td>
#     </tr>
#     <tr>
#       <td id="T_9b211_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_9b211_row2_col1" class="data row2 col1" >0.9426</td>
#       <td id="T_9b211_row2_col2" class="data row2 col2" >0.9431</td>
#       <td id="T_9b211_row2_col3" class="data row2 col3" >0.9426</td>
#       <td id="T_9b211_row2_col4" class="data row2 col4" >0.9422</td>
#     </tr>
#     <tr>
#       <td id="T_9b211_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_9b211_row3_col1" class="data row3 col1" >0.9589</td>
#       <td id="T_9b211_row3_col2" class="data row3 col2" >0.9594</td>
#       <td id="T_9b211_row3_col3" class="data row3 col3" >0.9589</td>
#       <td id="T_9b211_row3_col4" class="data row3 col4" >0.9586</td>
#     </tr>
#     <tr>
#       <td id="T_9b211_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_9b211_row4_col1" class="data row4 col1" >0.9477</td>
#       <td id="T_9b211_row4_col2" class="data row4 col2" >0.9496</td>
#       <td id="T_9b211_row4_col3" class="data row4 col3" >0.9477</td>
#       <td id="T_9b211_row4_col4" class="data row4 col4" >0.9471</td>
#     </tr>
#     <tr>
#       <td id="T_9b211_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_9b211_row5_col1" class="data row5 col1" >0.9477</td>
#       <td id="T_9b211_row5_col2" class="data row5 col2" >0.9492</td>
#       <td id="T_9b211_row5_col3" class="data row5 col3" >0.9477</td>
#       <td id="T_9b211_row5_col4" class="data row5 col4" >0.9472</td>
#     </tr>
#     <tr>
#       <td id="T_9b211_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_9b211_row6_col1" class="data row6 col1" >0.9503</td>
#       <td id="T_9b211_row6_col2" class="data row6 col2" >0.9518</td>
#       <td id="T_9b211_row6_col3" class="data row6 col3" >0.9503</td>
#       <td id="T_9b211_row6_col4" class="data row6 col4" >0.9498</td>
#     </tr>
#     <tr>
#       <td id="T_9b211_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_9b211_row7_col1" class="data row7 col1" >0.9263</td>
#       <td id="T_9b211_row7_col2" class="data row7 col2" >0.9278</td>
#       <td id="T_9b211_row7_col3" class="data row7 col3" >0.9263</td>
#       <td id="T_9b211_row7_col4" class="data row7 col4" >0.9255</td>
#     </tr>
#     <tr>
#       <td id="T_9b211_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_9b211_row8_col1" class="data row8 col1" >0.9426</td>
#       <td id="T_9b211_row8_col2" class="data row8 col2" >0.9432</td>
#       <td id="T_9b211_row8_col3" class="data row8 col3" >0.9426</td>
#       <td id="T_9b211_row8_col4" class="data row8 col4" >0.9422</td>
#     </tr>
#     <tr>
#       <td id="T_9b211_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_9b211_row9_col1" class="data row9 col1" >0.9392</td>
#       <td id="T_9b211_row9_col2" class="data row9 col2" >0.9401</td>
#       <td id="T_9b211_row9_col3" class="data row9 col3" >0.9392</td>
#       <td id="T_9b211_row9_col4" class="data row9 col4" >0.9386</td>
#     </tr>
#     <tr>
#       <td id="T_9b211_row10_col0" class="data row10 col0" >Rata-rata</td>
#       <td id="T_9b211_row10_col1" class="data row10 col1" >0.9433</td>
#       <td id="T_9b211_row10_col2" class="data row10 col2" >0.9444</td>
#       <td id="T_9b211_row10_col3" class="data row10 col3" >0.9433</td>
#       <td id="T_9b211_row10_col4" class="data row10 col4" >0.9428</td>
#     </tr>
#   </tbody>
# </table>
# ------------------------------------------------------------
#
#
# ========================= KNN Parameter k = 5 (Evaluasi pada Data Latih 80%) =========================
# Tabel Evaluasi 10-Fold CV pada Data Latih (k=5):
# <style type="text/css">
# </style>
# <table id="T_d429d" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_d429d_level0_col0" class="col_heading level0 col0" >Eksperimen (Fold)</th>
#       <th id="T_d429d_level0_col1" class="col_heading level0 col1" >Akurasi</th>
#       <th id="T_d429d_level0_col2" class="col_heading level0 col2" >Precision</th>
#       <th id="T_d429d_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_d429d_level0_col4" class="col_heading level0 col4" >F1 Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d429d_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_d429d_row0_col1" class="data row0 col1" >0.9486</td>
#       <td id="T_d429d_row0_col2" class="data row0 col2" >0.9512</td>
#       <td id="T_d429d_row0_col3" class="data row0 col3" >0.9486</td>
#       <td id="T_d429d_row0_col4" class="data row0 col4" >0.9480</td>
#     </tr>
#     <tr>
#       <td id="T_d429d_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_d429d_row1_col1" class="data row1 col1" >0.9486</td>
#       <td id="T_d429d_row1_col2" class="data row1 col2" >0.9506</td>
#       <td id="T_d429d_row1_col3" class="data row1 col3" >0.9486</td>
#       <td id="T_d429d_row1_col4" class="data row1 col4" >0.9480</td>
#     </tr>
#     <tr>
#       <td id="T_d429d_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_d429d_row2_col1" class="data row2 col1" >0.9494</td>
#       <td id="T_d429d_row2_col2" class="data row2 col2" >0.9508</td>
#       <td id="T_d429d_row2_col3" class="data row2 col3" >0.9494</td>
#       <td id="T_d429d_row2_col4" class="data row2 col4" >0.9490</td>
#     </tr>
#     <tr>
#       <td id="T_d429d_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_d429d_row3_col1" class="data row3 col1" >0.9640</td>
#       <td id="T_d429d_row3_col2" class="data row3 col2" >0.9652</td>
#       <td id="T_d429d_row3_col3" class="data row3 col3" >0.9640</td>
#       <td id="T_d429d_row3_col4" class="data row3 col4" >0.9637</td>
#     </tr>
#     <tr>
#       <td id="T_d429d_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_d429d_row4_col1" class="data row4 col1" >0.9477</td>
#       <td id="T_d429d_row4_col2" class="data row4 col2" >0.9506</td>
#       <td id="T_d429d_row4_col3" class="data row4 col3" >0.9477</td>
#       <td id="T_d429d_row4_col4" class="data row4 col4" >0.9470</td>
#     </tr>
#     <tr>
#       <td id="T_d429d_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_d429d_row5_col1" class="data row5 col1" >0.9520</td>
#       <td id="T_d429d_row5_col2" class="data row5 col2" >0.9542</td>
#       <td id="T_d429d_row5_col3" class="data row5 col3" >0.9520</td>
#       <td id="T_d429d_row5_col4" class="data row5 col4" >0.9515</td>
#     </tr>
#     <tr>
#       <td id="T_d429d_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_d429d_row6_col1" class="data row6 col1" >0.9572</td>
#       <td id="T_d429d_row6_col2" class="data row6 col2" >0.9594</td>
#       <td id="T_d429d_row6_col3" class="data row6 col3" >0.9572</td>
#       <td id="T_d429d_row6_col4" class="data row6 col4" >0.9567</td>
#     </tr>
#     <tr>
#       <td id="T_d429d_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_d429d_row7_col1" class="data row7 col1" >0.9374</td>
#       <td id="T_d429d_row7_col2" class="data row7 col2" >0.9408</td>
#       <td id="T_d429d_row7_col3" class="data row7 col3" >0.9374</td>
#       <td id="T_d429d_row7_col4" class="data row7 col4" >0.9365</td>
#     </tr>
#     <tr>
#       <td id="T_d429d_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_d429d_row8_col1" class="data row8 col1" >0.9529</td>
#       <td id="T_d429d_row8_col2" class="data row8 col2" >0.9552</td>
#       <td id="T_d429d_row8_col3" class="data row8 col3" >0.9529</td>
#       <td id="T_d429d_row8_col4" class="data row8 col4" >0.9523</td>
#     </tr>
#     <tr>
#       <td id="T_d429d_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_d429d_row9_col1" class="data row9 col1" >0.9486</td>
#       <td id="T_d429d_row9_col2" class="data row9 col2" >0.9511</td>
#       <td id="T_d429d_row9_col3" class="data row9 col3" >0.9486</td>
#       <td id="T_d429d_row9_col4" class="data row9 col4" >0.9479</td>
#     </tr>
#     <tr>
#       <td id="T_d429d_row10_col0" class="data row10 col0" >Rata-rata</td>
#       <td id="T_d429d_row10_col1" class="data row10 col1" >0.9506</td>
#       <td id="T_d429d_row10_col2" class="data row10 col2" >0.9529</td>
#       <td id="T_d429d_row10_col3" class="data row10 col3" >0.9506</td>
#       <td id="T_d429d_row10_col4" class="data row10 col4" >0.9501</td>
#     </tr>
#   </tbody>
# </table>
# ------------------------------------------------------------
#
#
# ========================= KNN Parameter k = 7 (Evaluasi pada Data Latih 80%) =========================
# Tabel Evaluasi 10-Fold CV pada Data Latih (k=7):
# <style type="text/css">
# </style>
# <table id="T_e6514" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_e6514_level0_col0" class="col_heading level0 col0" >Eksperimen (Fold)</th>
#       <th id="T_e6514_level0_col1" class="col_heading level0 col1" >Akurasi</th>
#       <th id="T_e6514_level0_col2" class="col_heading level0 col2" >Precision</th>
#       <th id="T_e6514_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_e6514_level0_col4" class="col_heading level0 col4" >F1 Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e6514_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_e6514_row0_col1" class="data row0 col1" >0.9512</td>
#       <td id="T_e6514_row0_col2" class="data row0 col2" >0.9542</td>
#       <td id="T_e6514_row0_col3" class="data row0 col3" >0.9512</td>
#       <td id="T_e6514_row0_col4" class="data row0 col4" >0.9505</td>
#     </tr>
#     <tr>
#       <td id="T_e6514_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_e6514_row1_col1" class="data row1 col1" >0.9520</td>
#       <td id="T_e6514_row1_col2" class="data row1 col2" >0.9552</td>
#       <td id="T_e6514_row1_col3" class="data row1 col3" >0.9520</td>
#       <td id="T_e6514_row1_col4" class="data row1 col4" >0.9514</td>
#     </tr>
#     <tr>
#       <td id="T_e6514_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_e6514_row2_col1" class="data row2 col1" >0.9512</td>
#       <td id="T_e6514_row2_col2" class="data row2 col2" >0.9527</td>
#       <td id="T_e6514_row2_col3" class="data row2 col3" >0.9512</td>
#       <td id="T_e6514_row2_col4" class="data row2 col4" >0.9507</td>
#     </tr>
#     <tr>
#       <td id="T_e6514_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_e6514_row3_col1" class="data row3 col1" >0.9666</td>
#       <td id="T_e6514_row3_col2" class="data row3 col2" >0.9681</td>
#       <td id="T_e6514_row3_col3" class="data row3 col3" >0.9666</td>
#       <td id="T_e6514_row3_col4" class="data row3 col4" >0.9663</td>
#     </tr>
#     <tr>
#       <td id="T_e6514_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_e6514_row4_col1" class="data row4 col1" >0.9460</td>
#       <td id="T_e6514_row4_col2" class="data row4 col2" >0.9489</td>
#       <td id="T_e6514_row4_col3" class="data row4 col3" >0.9460</td>
#       <td id="T_e6514_row4_col4" class="data row4 col4" >0.9453</td>
#     </tr>
#     <tr>
#       <td id="T_e6514_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_e6514_row5_col1" class="data row5 col1" >0.9529</td>
#       <td id="T_e6514_row5_col2" class="data row5 col2" >0.9552</td>
#       <td id="T_e6514_row5_col3" class="data row5 col3" >0.9529</td>
#       <td id="T_e6514_row5_col4" class="data row5 col4" >0.9523</td>
#     </tr>
#     <tr>
#       <td id="T_e6514_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_e6514_row6_col1" class="data row6 col1" >0.9572</td>
#       <td id="T_e6514_row6_col2" class="data row6 col2" >0.9597</td>
#       <td id="T_e6514_row6_col3" class="data row6 col3" >0.9572</td>
#       <td id="T_e6514_row6_col4" class="data row6 col4" >0.9566</td>
#     </tr>
#     <tr>
#       <td id="T_e6514_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_e6514_row7_col1" class="data row7 col1" >0.9409</td>
#       <td id="T_e6514_row7_col2" class="data row7 col2" >0.9450</td>
#       <td id="T_e6514_row7_col3" class="data row7 col3" >0.9409</td>
#       <td id="T_e6514_row7_col4" class="data row7 col4" >0.9399</td>
#     </tr>
#     <tr>
#       <td id="T_e6514_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_e6514_row8_col1" class="data row8 col1" >0.9554</td>
#       <td id="T_e6514_row8_col2" class="data row8 col2" >0.9582</td>
#       <td id="T_e6514_row8_col3" class="data row8 col3" >0.9554</td>
#       <td id="T_e6514_row8_col4" class="data row8 col4" >0.9549</td>
#     </tr>
#     <tr>
#       <td id="T_e6514_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_e6514_row9_col1" class="data row9 col1" >0.9512</td>
#       <td id="T_e6514_row9_col2" class="data row9 col2" >0.9542</td>
#       <td id="T_e6514_row9_col3" class="data row9 col3" >0.9512</td>
#       <td id="T_e6514_row9_col4" class="data row9 col4" >0.9505</td>
#     </tr>
#     <tr>
#       <td id="T_e6514_row10_col0" class="data row10 col0" >Rata-rata</td>
#       <td id="T_e6514_row10_col1" class="data row10 col1" >0.9524</td>
#       <td id="T_e6514_row10_col2" class="data row10 col2" >0.9551</td>
#       <td id="T_e6514_row10_col3" class="data row10 col3" >0.9524</td>
#       <td id="T_e6514_row10_col4" class="data row10 col4" >0.9518</td>
#     </tr>
#   </tbody>
# </table>
# ------------------------------------------------------------

# %% [markdown]
# # Persiapan Content Based Filtering

# %%
# Analisis Variabel Exercises

exercises = df['Exercises'].dropna()

ex_clean_analysis = exercises.str.replace(r'\band\b|\bor\b', ',', regex=True)
ex_split_analysis = ex_clean_analysis.str.split(',').explode().str.strip().str.lower().str.replace(r'\.$', '', regex=True)
ex_split_analysis = ex_split_analysis[ex_split_analysis != ""]

ex_counts = ex_split_analysis.value_counts().head(10)
plt.figure(figsize=(10, 6))
sns.barplot(x=ex_counts.values, y=ex_counts.index, palette='viridis')
plt.title('Top 10 Exercises (Analisis Awal)')
plt.xlabel('Jumlah Kemunculan')
plt.ylabel('Exercise')
plt.tight_layout()
plt.show()
print(f"Total exercise unik (analisis awal): {ex_split_analysis.nunique()}")
print("Jenis exercises unik: ", df["Exercises"].unique())
# Out:
# /tmp/ipython-input-2459768395.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=ex_counts.values, y=ex_counts.index, palette='viridis')
# Total exercise unik (analisis awal): 68
# Jenis exercises unik:  ['Squats, deadlifts, bench presses, and overhead presses, lunges, push up, Squat, Bench press, push-up, Deadlift, kettlebell swing, Pull-up, lat pull-down, Plank, side-plank'
#  'Squats, deadlifts, bench presses, and overhead presses, Bodyweight squat, Push-up, Dumbbell deadlift, Pull-up, lat pull-down, Plank, side plank'
#  'Squats, yoga, deadlifts, bench presses, and overhead presses, Barbell squat, dumbbell squat, Dumbbell bench press, Deadlift, Assisted pull-up, lat pull-down, Plank, Russian twist'
#  'Squats, yoga, cycling, dumbbell), Dumbbell bench press, Deadlift, Pull-up, lat pull-down, plank'
#  'Squats, deadlifts, bench presses, and overhead presses, Squat, Bench press, push-up, Deadlift, kettlebell swing, Pull-up, lat pull-down, Plank, side-plank'
#  'Squats, yoga, deadlifts, bench presses, and overhead presses, dumbbell), Dumbbell bench press, Deadlift, Pull-up, lat pull-down, plank'
#  'Squats, deadlifts, bench presses, and overhead presses, Squat, Bench press, push-up, Deadlift, hip hinge, Pull-up, lat pull-down, Plank, side-plank'
#  'Squats, deadlifts, bench presses, and overhead presses, dumbbell squat, Push-up, Dumbbell deadlift, Pull-up, lat pull-down, Plank, side-plank'
#  'Squats, yoga, deadlifts, bench presses, and overhead presses, Squat, Dumbbell bench press, Deadlift, Assisted pull-up, lat pull-down, Plank, Russian twist'
#  'Squats, yoga, deadlifts, bench presses, and overhead presses, Squat, Dumbbell bench press, Deadlift, Pull-up, lat pull-down, Plank'
#  'Brisk walking, cycling, swimming, running, or dancing., Barbell back squat, goblet squat, Dumbbell bench press, Deadlift, kettlebell swing, Lat pull-down, pull-up asistensi, Plank, side-plank'
#  'Brisk walking, cycling, swimming, running, or dancing., dumbbell squat, Push-up, Dumbbell deadlift, Lat pull-down, pull-up asistensi, Plank, side-plank'
#  'Walking, Yoga, Swimming., Goblet squat, dumbbell squat, Machine or dumbbell bench press, Deadlift, Assisted pull-up, lat pull-down, Plank, Russian twist'
#  'brisk walking, cycling, swimming, or dancing., Squat, Dumbbell bench press, Deadlift, Pull-up, lat pull-down asistensi, Plank'
#  'Brisk walking, cycling, swimming, running, or dancing., brisk walking, treadmill incline, Stationary bike, elliptical, aqua jogging, squat, dumbbell row'
#  'Brisk walking, cycling, swimming, running, or dancing., brisk walking, treadmill incline, Stationary bike, aqua jogging, squat, resistance band row'
#  'Walking, Yoga, Swimming., brisk walking, incline treadmill, Stationary bike, aqua jogging, squat, dumbbell press'
#  'brisk walking, cycling, swimming, or dancing., incline treadmill, Stationary bike, aqua jogging'
#  'Squats, deadlifts, bench presses, and overhead presses, Goblet squat, Dumbbell chest press, Romanian deadlift, Seated row, Farmers walk'
#  'Squats, deadlifts, bench presses, and overhead presses, Goblet squat, Dumbbell bench press, Hip hinge, Seated row, Wall-squat'
#  'Squats, yoga, deadlifts, bench presses, and overhead presses, Leg press, Dumbbell incline press, Deadlift, Romanian deadlift, Cable row, Plank, reverse crunch'
#  'Squats, yoga, deadlifts, bench presses, and overhead presses, Leg press, Dumbbell incline press, Hip hinge, Cable row, Wall-squat, plank'
#  'Squats, deadlifts, bench presses, and overhead presses, Goblet squat, barbell back-squat, Dumbbell chest press, Romanian deadlift, Seated cable row, Farmers walk'
#  'Squats, yoga, deadlifts, bench presses, and overhead presses, Leg press, Dumbbell incline press, Romanian deadlift, Cable row, Plank, reverse crunch'
#  'Brisk walking, cycling, swimming, running, or dancing., Leg press, Dumbbell incline press, Romanian deadlift, Seated cable row, Farmers walk'
#  'Brisk walking, cycling, swimming, running, or dancing., Goblet squat, Dumbbell bench press, Hip hinge, Seated row, Wall-squat'
#  'Walking, Yoga, Swimming., Leg press, Dumbbell incline press, Romanian deadlift, Cable row, Reverse crunch, plank'
#  'brisk walking, cycling, swimming, or dancing., Leg press, Dumbbell incline press, Hip hinge, Cable row, Wall-squat, plank'
#  'Brisk walking, cycling, swimming, running, or dancing., brisk walking, Stationary bike, outdoor cycling, Elliptical, stair climber, leg press, chest press'
#  'Brisk walking, cycling, swimming, running, or dancing., brisk walking, Elliptical, stair climber, Stationary bike'
#  'Walking, Yoga, Swimming., brisk walking, Elliptical, Stationary bike, outdoor cycling'
#  'brisk walking, cycling, swimming, or dancing., Elliptical, stair climber, Stationary bikes'
#  'Squats, deadlifts, and overhead presses, Goblet squat, Dumbbell chest press, Romanian deadlift, Seated row, Farmers walk'
#  'Squats, deadlifts, and overhead presses, Goblet squat, Hip hinge, Seated row, Wall-squat'
#  'Squats, yoga, deadlifts, and overhead presses, Leg press, Dumbbell incline press, Deadlift, Romanian deadlift, Cable row, Plank, reverse crunch'
#  'Squats, yoga, deadlifts, and overhead presses, Leg press, Dumbbell incline press, Hip hinge, Cable row, Wall-squat, plank'
#  'Squats, deadlifts, and overhead presses, Goblet squat, barbell back-squat, Dumbbell chest press, Romanian deadlift, Seated cable row, Farmers walk'
#  'Squats, yoga, deadlifts, and overhead presses, Leg press, Dumbbell incline press, Romanian deadlift, Cable row, Plank, reverse crunch'
#  'Brisk walking, cycling, swimming, running, or dancing., Goblet squat, Hip hinge, Seated row, Wall-squat'
#  'Squats, deadlifts, and overhead presses, Chair squat, Dumbbell incline press, Hip hinge, Lat pull-down, resistance band row, Wall-plank, plank'
#  'Squats, deadlifts, and overhead presses, Chair squat, Chest press, Hip bridge, Band row, plank, wall-plank'
#  'Squats, yoga, deadlifts, and overhead presses, Leg extension, Chest press, Hip hinge, Resistance band row, Wall-squat, plank'
#  'Squats, yoga, deadlifts, and overhead presses, Chair squat, chest press, Hip bridge, Resistance band row, plank, wall-plank'
#  'Squats, deadlifts, and overhead presses, Chair squat, leg press, Dumbbell incline press, chest press, Hip hinge, Resistance band row, Wall-plank, front Plank'
#  'Squats, deadlifts, and overhead presses, Chair squat, leg press, Chest press, Hip bridge, Band row, Plank, wall-plank'
#  'Squats, yoga, deadlifts, and overhead presses, Leg extension, chest press, Hip bridge, Resistance band row, Wall-squat, Plank'
#  'Squats, yoga, deadlifts, and overhead presses, Leg press, leg extension, chest press, Hip bridge, Resistance band row, Plank, wall-plank'
#  'Brisk walking, cycling, swimming, running, or dancing., Chair squat, chest press, dumbbell press, Hip hinge, Resistance band row, Wall-plank, front Plank'
#  'Brisk walking, cycling, swimming, running, or dancing., Chair squat, Chest press, Hip bridge, Band row, Plank, wall-plank'
#  'Walking, Yoga, Swimming., Leg extension, leg curl, chest press, Hip bridge, Resistance band row, Wall-squat'
#  'brisk walking, cycling, swimming, or dancing., leg extension, chest press, Hip bridge, Resistance band row, Plank, wall-plank'
#  'Brisk walking, cycling, swimming, running, or dancing., brisk walking, treadmill, aqua jogging, Stationary bike, leg press, resistance band row, wall-squat'
#  'Brisk walking, cycling, swimming, running, or dancing., brisk walking, treadmill, aqua jogging, Stationary bike'
#  'Walking, Yoga, Swimming., brisk walking, treadmill, aqua jogging, Stationary bike'
#  'brisk walking, cycling, swimming, or dancing., treadmill, aqua jogging, Stationary bike'
#  'Squats, deadlifts, bench presses, and overhead presses, Leg press, Dumbbell incline press, Romanian deadlift, Seated cable row, Farmers walk'
#  'Squats, yoga, deadlifts, bench presses, and overhead presses, Leg press, Dumbbell incline press, Romanian deadlift, Cable row, Reverse crunch, plank'
#  'Brisk walking, cycling, swimming, running, or dancing., Squat, Bench press, push-up, Deadlift, hip hinge, Pull-up, lat pull-down, Plank, side-plank'
#  'Brisk walking, cycling, swimming, running, or dancing., dumbbell squat, Push-up, Dumbbell deadlift, Pull-up, lat pull-down, Plank, side-plank'
#  'Walking, Yoga, Swimming., Squat, Dumbbell bench press, Deadlift, Assisted pull-up, lat pull-down, Plank, Russian twist'
#  'brisk walking, cycling, swimming, or dancing., Squat, Dumbbell bench press, Deadlift, Pull-up, lat pull-down, Plank'
#  'Squats, deadlifts, bench presses, and overhead presses, Barbell back squat, goblet squat, Dumbbell bench press, Deadlift, kettlebell swing, Lat pull-down, pull-up asistensi, Plank, side-plank'
#  'Squats, deadlifts, bench presses, and overhead presses, dumbbell squat, Push-up, Dumbbell deadlift, Lat pull-down, pull-up asistensi, Plank, side-plank'
#  'Squats, yoga, deadlifts, bench presses, and overhead presses, Goblet squat, dumbbell squat, Machine or dumbbell bench press, Deadlift, Assisted pull-up, lat pull-down, Plank, Russian twist'
#  'Squats, yoga, deadlifts, bench presses, and overhead presses, Squat, Dumbbell bench press, Deadlift, Pull-up, lat pull-down asistensi, Plank']

# %%
# Analisis Variabel Equipment

equipment = df['Equipment'].dropna()

eq_clean_analysis = equipment.str.replace(r'\band\b|\bor\b|[.;]', ',', regex=True)
eq_split_analysis = eq_clean_analysis.str.split(',').explode().str.strip().str.lower()
eq_split_analysis = eq_split_analysis[eq_split_analysis != ""].replace({'a blood glucose monitor': 'blood glucose monitor', 'treadmills': 'treadmill'})

eq_counts = eq_split_analysis.value_counts().head(10)
plt.figure(figsize=(10, 6))
sns.barplot(x=eq_counts.values, y=eq_counts.index, palette='viridis')
plt.title('Top 10 Equipment (Analisis Awal)')
plt.xlabel('Jumlah Kemunculan')
plt.ylabel('Equipment')
plt.tight_layout()
plt.show()
print(f"Total equipment unik: {eq_split_analysis.nunique()}")
print("Jenis equipment unik: ", df["Equipment"].unique())
# Out:
# /tmp/ipython-input-1209144429.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=eq_counts.values, y=eq_counts.index, palette='viridis')
# Total equipment unik: 43
# Jenis equipment unik:  ['Dumbbells and barbells, Dumbbell, Flat bench, Pull-up bar, resistance band, Kettlebell, Yoga mat'
#  'Light athletic shoes, resistance bands, and light dumbbells., Dumbbell, Pull-up bar, resistance band, Yoga mat, Kettlebell, strap'
#  'Dumbbells, barbells and Blood glucose monitor, Barbell, Dumbbell, Pull-up bar, Lat pull-down machine, Kettlebell, Yoga mat, medicine ball'
#  'Light athletic shoes, resistance bands, light dumbbells and a Blood glucose monitor., Dumbbell, Pull-up bar, lat pull-down, Yoga mat, Kettlebell'
#  'Dumbbells and barbells, Barbell, Dumbbell, Flat bench, bench, Pull-up bar, lat pull-down machine, Yoga mat'
#  'Light athletic shoes, resistance bands, and light dumbbells., Dumbbell, Pull-up bar, lat pull-down, Yoga mat, Kettlebell'
#  'Dumbbells, barbells and Blood glucose monitor, Barbell, Dumbbell, Pull-up bar, lat pull-down, Kettlebell, Yoga mat, medicine ball'
#  'Light athletic shoes, resistance bands, light dumbbells and a Blood glucose monitor., Dumbbell, Lat pull-down machine, Kettlebell, Yoga mat, Resistance band'
#  'Ellipticals, Indoor Rowers, Treadmills, Rowing machine, Barbell, Dumbbell, Flat bench, incline bench, Pull-up bar, Yoga mat, Kettlebell'
#  'Ellipticals, Indoor Rowers, Treadmills, Rowing machine, Dumbbell, Pull-up bar, lat pull-down, Yoga mat, Kettlebell'
#  'Kettlebell, Dumbbells, Yoga Mat, Dumbbell, Bench, Lat pull-down, assisted pull-up machine, Medicine ball'
#  'Kettlebell, Dumbbells, Yoga Mat, Treadmill, Dumbbell, Lat pull-down machine, Yoga mat, Resistance band'
#  'Ellipticals, Indoor Rowers, Treadmills, Rowing machine, Barbell, Dumbbell, Flat bench, incline bench, lat pull-down machine, Yoga mat, Kettlebell'
#  'Ellipticals, Indoor Rowers,Treadmills, Rowing machine'
#  'Kettlebell, Dumbbells, Yoga Mat'
#  'Kettlebell, Dumbbells, Yoga Mat, Treadmill'
#  'Dumbbells and barbells, Dumbbell, bench, Cable row machine, Kettlebell'
#  'Light athletic shoes, resistance bands, and light dumbbells., Dumbbell, bench, Resistance band, Seated row machine, Yoga mat'
#  'Dumbbells, barbells and Blood glucose monitor, Leg press machine, Chest press, incline press machine, Cable row machine, seated row, Dumbbell, Yoga mat'
#  'Light athletic shoes, resistance bands, light dumbbells and a Blood glucose monitor., Leg press machine, Dumbbell, Cable row machine, Resistance band'
#  'Dumbbells and barbells, Dumbbell, Barbell squat rack, Cable row machine, Kettlebell, Farmer walk handles'
#  'Light athletic shoes, resistance bands, and light dumbbells., Dumbbell, bench, Seated row machine, Resistance band'
#  'Dumbbells, barbells and Blood glucose monitor, Leg press machine, Dumbbell, Cable row machine, Resistance band, Yoga mat'
#  'Light athletic shoes, resistance bands, light dumbbells and a Blood glucose monitor., Leg press machine, Dumbbell, Cable row machine, Resistance band, Wall plank mat setup'
#  'Ellipticals, Indoor Rowers, Treadmills, Rowing machine, Leg press machine, Dumbbell, Barbell, Smith machine, Cable row machine, Resistance band'
#  'Ellipticals, Indoor Rowers, Treadmills, Rowing machine, Dumbbell, bench, Seated row machine, Resistance band'
#  'Kettlebell, Dumbbells, Yoga Mat, Leg press machine, Dumbbell, Cable row machine, Resistance band, Yoga mat'
#  'Kettlebell, Dumbbells, Yoga Mat, Treadmill, Leg press machine, Dumbbell, Cable row machine, Resistance band'
#  'Dumbbells and barbells, Resistance band, bench, Lat pull-down machine, Dumbbell, Box'
#  'Light athletic shoes, resistance bands, and light dumbbells., Chest press machine, resistance bands, Yoga Mat'
#  'Dumbbells, barbells and Blood glucose monitor, Leg extension & leg curl machine, Chest press machine, Resistance band, Kettlebell'
#  'Light athletic shoes, resistance bands, light dumbbells and a Blood glucose monitor., Leg press machine, Chest press machine, Kettlebell, Resistance band'
#  'Dumbbells and barbells, Leg press machine, Resistance band, Chest press machine, Dumbbell, Kettlebell'
#  'Light athletic shoes, resistance bands, and light dumbbells., Chest press machine, Leg press, band row, Resistance band, Yoga mat'
#  'Dumbbells, barbells and Blood glucose monitor, Leg extension, leg curl machine, Chest press machine, Resistance band, Kettlebell'
#  'Light athletic shoes, resistance bands, light dumbbells and a Blood glucose monitor., Leg press, Chest press machine, Resistance band, Kettlebell, Yoga mat'
#  'Ellipticals, Indoor Rowers, Treadmills, Rowing machine, leg press machine, Chest press machine, Dumbbell, Kettlebell, Resistance band, Yoga mat'
#  'Ellipticals, Indoor Rowers, Treadmills, Rowing machine, Leg press machine, Chest press machine, Resistance band, Yoga mat'
#  'Kettlebell, Dumbbells, Yoga Mat, Leg extension, leg curl machine, Chest press machine, Resistance band'
#  'Kettlebell, Dumbbells, Yoga Mat, Treadmill, Leg press machine, Chest press machine, Resistance band, plank setup'
#  'Dumbbells and barbells, Leg press machine, Dumbbell, Barbell, Smith machine, Cable row machine, Resistance band'
#  'Equipment Required, Dumbbell, bench, Cable row machine, Kettlebell'
#  'Dumbbells and barbells, Dumbbell, bench, Resistance band, Seated row machine, Yoga mat'
#  'Light athletic shoes, resistance bands, and light dumbbells., Leg press machine, Chest press, incline press machine, Cable row machine, seated row, Dumbbell, Yoga mat'
#  'Dumbbells, barbells and Blood glucose monitor, Leg press machine, Dumbbell, Cable row machine, Resistance band'
#  'Light athletic shoes, resistance bands, light dumbbells and a Blood glucose monitor., Dumbbell, bench, Cable row machine, Kettlebell'
#  'Light athletic shoes, resistance bands, light dumbbells and a Blood glucose monitor., Dumbbell, Barbell squat rack, Cable row machine, Kettlebell, Farmer walk handles'
#  'Dumbbells and barbells, Dumbbell, bench, Seated row machine, Resistance band'
#  'Light athletic shoes, resistance bands, and light dumbbells., Leg press machine, Dumbbell, Cable row machine, Resistance band, Yoga mat'
#  'Dumbbells, barbells and Blood glucose monitor, Leg press machine, Dumbbell, Cable row machine, Resistance band, Wall plank mat setup'
#  'Light athletic shoes, resistance bands, light dumbbells and a Blood glucose monitor., Leg press machine, Dumbbell, Barbell, Smith machine, Cable row machine, Resistance band'
#  'Ellipticals, Indoor Rowers, Treadmills, Rowing machine, Leg press machine, Dumbbell, Cable row machine, Resistance band, Yoga mat'
#  'Kettlebell, Dumbbells, Yoga Mat, Leg press machine, Dumbbell, Cable row machine, Resistance band'
#  'Kettlebell, Dumbbells, Yoga Mat, Treadmill, Leg press machine, Dumbbell, Barbell, Smith machine, Cable row machine, Resistance band'
#  'Kettlebell, Dumbbells, Yoga Mat, Treadmill, Resistance band, bench, Lat pull-down machine, Dumbbell, Box'
#  'Equipment Required, Chest press machine, resistance bands, Yoga Mat'
#  'Dumbbells and barbells, Leg extension & leg curl machine, Chest press machine, Resistance band, Kettlebell'
#  'Light athletic shoes, resistance bands, and light dumbbells., Leg press machine, Chest press machine, Kettlebell, Resistance band'
#  'Dumbbells, barbells and Blood glucose monitor, Resistance band, bench, Lat pull-down machine, Dumbbell, Box'
#  'Light athletic shoes, resistance bands, light dumbbells and a Blood glucose monitor., Chest press machine, resistance bands, Yoga Mat'
#  'Dumbbells, barbells and Blood glucose monitor, Leg press machine, Resistance band, Chest press machine, Dumbbell, Kettlebell'
#  'Light athletic shoes, resistance bands, light dumbbells and a Blood glucose monitor., Chest press machine, Leg press, band row, Resistance band, Yoga mat'
#  'Dumbbells and barbells, Leg extension, leg curl machine, Chest press machine, Resistance band, Kettlebell'
#  'Light athletic shoes, resistance bands, and light dumbbells., Leg press, Chest press machine, Resistance band, Kettlebell, Yoga mat'
#  'Dumbbells, barbells and Blood glucose monitor, leg press machine, Chest press machine, Dumbbell, Kettlebell, Resistance band, Yoga mat'
#  'Light athletic shoes, resistance bands, light dumbbells and a Blood glucose monitor., Leg press machine, Chest press machine, Resistance band, Yoga mat'
#  'Ellipticals, Indoor Rowers, Treadmills, Rowing machine, Leg extension, leg curl machine, Chest press machine, Resistance band, Kettlebell'
#  'Ellipticals, Indoor Rowers, Treadmills, Rowing machine, Leg press machine, Chest press machine, Resistance band, Kettlebell, plank setup'
#  'Kettlebell, Dumbbells, Yoga Mat, leg press machine, Chest press machine, Dumbbell, Resistance band, Yoga mat'
#  'Kettlebell, Dumbbells, Yoga Mat, Treadmill, Leg press machine, Chest press machine, Resistance band, Yoga mat'
#  'Kettlebell, Dumbbells, Yoga Mat, Resistance band, bench, Lat pull-down machine, Dumbbell, Box'
#  'Kettlebell, Dumbbells, Yoga Mat, Treadmill, Chest press machine, resistance bands, Yoga Mat'
#  'Equipment Required, Leg extension & leg curl machine, Chest press machine, Resistance band, Kettlebell'
#  'Dumbbells and barbells, Leg press machine, Chest press machine, Kettlebell, Resistance band'
#  'Light athletic shoes, resistance bands, and light dumbbells., Resistance band, bench, Lat pull-down machine, Dumbbell, Box'
#  'Dumbbells, barbells and Blood glucose monitor, Chest press machine, resistance bands, Yoga Mat'
#  'Light athletic shoes, resistance bands, light dumbbells and a Blood glucose monitor., Leg extension & leg curl machine, Chest press machine, Resistance band, Kettlebell'
#  'Light athletic shoes, resistance bands, and light dumbbells., Leg press machine, Resistance band, Chest press machine, Dumbbell, Kettlebell'
#  'Dumbbells, barbells and Blood glucose monitor, Chest press machine, Leg press, band row, Resistance band, Yoga mat'
#  'Light athletic shoes, resistance bands, light dumbbells and a Blood glucose monitor., Leg extension, leg curl machine, Chest press machine, Resistance band, Kettlebell'
#  'Dumbbells and barbells, Leg press, Chest press machine, Resistance band, Kettlebell, Yoga mat'
#  'Light athletic shoes, resistance bands, and light dumbbells., leg press machine, Chest press machine, Dumbbell, Kettlebell, Resistance band, Yoga mat'
#  'Dumbbells, barbells and Blood glucose monitor, Leg press machine, Chest press machine, Resistance band, Yoga mat'
#  'Kettlebell, Dumbbells, Yoga Mat, Leg press machine, Chest press machine, Resistance band, Yoga mat'
#  'Kettlebell, Dumbbells, Yoga Mat, Treadmill, Leg extension, leg curl machine, Chest press machine, Resistance band'
#  'Ellipticals, Indoor Rowers, Treadmills, Rowing machine, Resistance band, bench, Lat pull-down machine, Dumbbell, Box'
#  'Kettlebell, Dumbbells, Yoga Mat, Chest press machine, resistance bands, Yoga Mat'
#  'Kettlebell, Dumbbells, Yoga Mat, Treadmill, Leg extension & leg curl machine, Chest press machine, Resistance band'
#  'Equipment Required, Leg press machine, Chest press machine, Kettlebell, Resistance band'
#  'Dumbbells and barbells, leg press machine, Chest press machine, Dumbbell, Kettlebell, Resistance band, Yoga mat'
#  'Light athletic shoes, resistance bands, and light dumbbells., Leg press machine, Chest press machine, Resistance band, Yoga mat'
#  'Light athletic shoes, resistance bands, light dumbbells and a Blood glucose monitor., Leg press machine, Chest press machine, Resistance band, Kettlebell, plank setup'
#  'Ellipticals, Indoor Rowers, Treadmills, Rowing machine, Chest press machine, resistance bands, Yoga Mat'
#  'Kettlebell, Dumbbells, Yoga Mat, Leg extension & leg curl machine, Chest press machine, Resistance band'
#  'Kettlebell, Dumbbells, Yoga Mat, Treadmill, Leg press machine, Chest press machine, Resistance band'
#  'Equipment Required, Resistance band, bench, Lat pull-down machine, Dumbbell, Box'
#  'Dumbbells and barbells, Chest press machine, resistance bands, Yoga Mat'
#  'Light athletic shoes, resistance bands, and light dumbbells., Leg extension & leg curl machine, Chest press machine, Resistance band, Kettlebell'
#  'Dumbbells, barbells and Blood glucose monitor, Leg press machine, Chest press machine, Kettlebell, Resistance band'
#  'Light athletic shoes, resistance bands, light dumbbells and a Blood glucose monitor., Leg press machine, Resistance band, Chest press machine, Dumbbell, Kettlebell'
#  'Dumbbells and barbells, Chest press machine, Leg press, band row, Resistance band, Yoga mat'
#  'Light athletic shoes, resistance bands, and light dumbbells., Leg extension, leg curl machine, Chest press machine, Resistance band, Kettlebell'
#  'Dumbbells, barbells and Blood glucose monitor, Leg press, Chest press machine, Resistance band, Kettlebell, Yoga mat'
#  'Light athletic shoes, resistance bands, light dumbbells and a Blood glucose monitor., leg press machine, Chest press machine, Dumbbell, Kettlebell, Resistance band, Yoga mat'
#  'Dumbbells and barbells, Leg press machine, Chest press machine, Resistance band, Yoga mat'
#  'Dumbbells, barbells and Blood glucose monitor, Leg press machine, Chest press machine, Resistance band, Kettlebell, plank setup'
#  'Kettlebell, Dumbbells, Yoga Mat, Leg press machine, Chest press machine, Resistance band, plank setup'
#  'Ellipticals, Indoor Rowers, Treadmills, Rowing machine, Leg extension & leg curl machine, Chest press machine, Resistance band, Kettlebell'
#  'Kettlebell, Dumbbells, Yoga Mat, Leg press machine, Chest press machine, Resistance band'
#  'Light athletic shoes, resistance bands, and light dumbbells., Leg press machine, Chest press machine, Resistance band, Kettlebell, plank setup'
#  'Ellipticals, Indoor Rowers, Treadmills, Rowing machine, Leg press machine, Chest press machine, Kettlebell, Resistance band'
#  'Dumbbells and barbells, Leg press machine, Chest press machine, Resistance band, Kettlebell, plank setup'
#  'Equipment Required, Leg press machine, Resistance band, Chest press machine, Dumbbell, Kettlebell'
#  'Light athletic shoes, resistance bands, light dumbbells and a Blood glucose monitor.'
#  'Kettlebell, Dumbbells, Yoga Mat, Treadmill, Leg press machine, Resistance band, Chest press machine, Dumbbell'
#  'Equipment Required, Chest press machine, Leg press, band row, Resistance band, Yoga mat'
#  'Dumbbells, barbells and Blood glucose monitor'
#  'Kettlebell, Dumbbells, Yoga Mat, Leg press machine, Resistance band, Chest press machine, Dumbbell'
#  'Kettlebell, Dumbbells, Yoga Mat, Treadmill, Chest press machine, Leg press, band row, Resistance band, Yoga mat'
#  'Equipment Required, Leg extension, leg curl machine, Chest press machine, Resistance band, Kettlebell'
#  'Light athletic shoes, resistance bands, and light dumbbells.'
#  'Ellipticals, Indoor Rowers, Treadmills, Rowing machine, Leg press machine, Resistance band, Chest press machine, Dumbbell, Kettlebell'
#  'Kettlebell, Dumbbells, Yoga Mat, Chest press machine, Leg press, band row, Resistance band, Yoga mat'
#  'Equipment Required, Leg press, Chest press machine, Resistance band, Kettlebell, Yoga mat'
#  'Dumbbells and barbells'
#  'Ellipticals, Indoor Rowers, Treadmills, Rowing machine, Barbell, Dumbbell, Flat bench, bench, Pull-up bar, lat pull-down machine, Yoga mat'
#  'Kettlebell, Dumbbells, Yoga Mat, Barbell, Dumbbell, Pull-up bar, lat pull-down, Yoga mat, medicine ball'
#  'Dumbbells and barbells, Barbell, Dumbbell, Flat bench, incline bench, lat pull-down machine, Yoga mat, Kettlebell'
#  'Dumbbells, barbells and Blood glucose monitor, Dumbbell, Bench, Lat pull-down, assisted pull-up machine, Kettlebell, Medicine ball'
#  'Light athletic shoes, resistance bands, light dumbbells and a Blood glucose monitor., Dumbbell, Lat pull-down machine, Yoga mat, Kettlebell, Resistance band'
#  'Ellipticals, Indoor Rowers,Treadmills, and Rowing machine'
#  'Ellipticals, Indoor Rowers, Treadmills, and Rowing machine, Barbell, Dumbbell, Flat bench, incline bench, Pull-up bar, Yoga mat, Kettlebell'
#  'Ellipticals, Indoor Rowers, Treadmills, and Rowing machine, Barbell, Dumbbell, Flat bench, incline bench, lat pull-down machine, Yoga mat, Kettlebell'
#  'Ellipticals, Indoor Rowers, Treadmills, and Rowing machine, Leg press machine, Dumbbell, Barbell, Smith machine, Cable row machine, Resistance band'
#  'Ellipticals, Indoor Rowers, Treadmills, and Rowing machine, leg press machine, Chest press machine, Dumbbell, Kettlebell, Resistance band, Yoga mat']

# %% [markdown]
# ## Data Preparation

# %%
# Ambil kolom yang relevan
preparation = df[['Hypertension', 'Diabetes', 'Fitness Type', 'Level', 'Fitness Goal', 'Sex', 'Age Group', 'Exercises', 'Equipment', 'Diet']].copy()

# %%
# Normalisasi Data

EXERCISE_NORM_MAP = {
    'Squats': 'Squat',
    'Barbell Back-Squat': 'Barbell Back Squat',
    'Barbell Squat': 'Barbell Back Squat',
    'Bench Presses': 'Bench Press',
    'Push-Up': 'Push Up',
    'Side-Plank': 'Side Plank',
    'Wall-Plank': 'Wall Plank',
    'Wall-Squat': 'Wall Squat',
    'Lat Pull-Down Asistensi': 'Assisted Lat Pull-Down',
    'Pull-Up Asistensi': 'Assisted Pull-Up',
    'Stationary Bikes': 'Stationary Bike',
    'Dancing': 'Cardio Dance',
    'Cycling': 'Outdoor Cycling',
    'Treadmill Inclinen': 'Treadmill',
    'Treadmill Incline': 'Treadmill',
    'Incline Treadmill': 'Treadmill',
    'Dumbbell Bench Press': 'Bench Press',
    'Dumbbell Chest Press': 'Chest Press',
    'Dumbbell Deadlift': 'Deadlift',
    'Dumbbell Incline Press': 'Chest Press',
    'Dumbbell Press': 'Chest Press',
    'Dumbbell': '',
    'Bodyweight': 'Squat',
    'Bodyweight Squat': 'Squat',
    'Deadlifts': 'Deadlift',
    'Machine': ''
}

EQUIPMENT_NORM_MAP = {
    'Barbells': 'Barbell',
    'Barbell Squat Rack': 'Squat Rack',
    'Dumbbells': 'Dumbbell',
    'Light Dumbbells': 'Dumbbell',
    'Resistance Bands': 'Resistance Band',
    'Treadmills': 'Treadmill machine',
    'Band Row': 'Resistance Band',
    'Chest Press': 'Chest Press Machine',
    'Ellipticals': 'Ellipticals Machine',
    'Leg Press': 'Leg Press Machine',
    'Seated Row': 'Seated Row Machine',
    'Wall Plank Mat Setup': 'Yoga Mat',
    'Leg Extension': 'Leg Extension Machine',
    'Leg Press Machine': 'Leg Press Machine',
    'Cable Row': 'Cable Row Machine',
    'Lat Pull-Down': 'Lat Pull-Down Machine',
    'Equipment Required': ''
}

# %%
# fungsi cleaning text

def clean_items(text, normalization_map):
    if not isinstance(text, str):
        return []

    # Pre-cleaning typo spesifik
    text = text.replace('Resistance Bandyoga Mat', 'Resistance Band | Yoga Mat')
    text = text.replace('Leg Extension & Leg Curl Machine', 'Leg Extension Machine | Leg Curl Machine')

    text = text.replace("(", "").replace(")", "").replace(";", "|").replace("&", "|")
    text = text.replace(" and ", "|").replace(" or ", "|").replace(",", "|")

    # Split kata dan bersihkan whitespace
    items = [item.strip() for item in text.split('|') if item.strip()]

    # Normalisasi dan Finalisasi per item
    cleaned_list = []
    for item in items:
        # Hapus artikel di depan
        item_lower_check = item.lower()
        if item_lower_check.startswith("a "): item = item[2:].strip()
        elif item_lower_check.startswith("an "): item = item[3:].strip()
        elif item_lower_check.startswith("and "): item = item[4:].strip()
        elif item_lower_check.startswith("or "): item = item[3:].strip()

        # Hapus karakter non-alfanumerik di belakang
        item = re.sub(r'[^\w\s\-]+$', '', item).strip()

        # Selalu konversi ke Title Case sebelum mapping
        item = item.title()

        if item in normalization_map:
            item = normalization_map[item]

        if item and item.lower() not in ["and", "or"]:
            cleaned_list.append(item)

    # Hapus duplikat setelah normalisasi
    return list(dict.fromkeys(cleaned_list))

# %%
# Membersihkan item dalam series
def normalize_text_column(text_col_series, norm_map):

    def clean_and_join(text):
        if not isinstance(text, str): return text
        items = clean_items(text, norm_map)
        return ', '.join(items) if items else text
    return text_col_series.apply(clean_and_join)

# String Diet Baru berdasarkan masukan Ahli Gizi (dengan acuan Tumpengku - Kemenkes)
TUMPENG_GIZI_DIET_STRING = (
    "Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagung, Singkong, Ubi); "
    "Mineral & Serat: (Bayam, Kangkung, Wortel, Tomat, Brokoli, Jeruk, Apel, Pisang, Pepaya); "
    "Protein: (Tahu, Tempe, Kacang-kacangan, Ikan, Ayam Tanpa Kulit, Telur, Daging Tanpa Lemak, Susu Rendah Lemak)"
)

# Mengganti string diet lama dengan string Tumpeng Gizi standar
def replace_with_tumpeng_gizi(original_diet_string):
    return TUMPENG_GIZI_DIET_STRING

# %%
print("Menormalisasi item individual di 'Exercises'")
preparation['Exercises'] = normalize_text_column(preparation['Exercises'], EXERCISE_NORM_MAP)

print("\nMenormalisasi item individual di 'Equipment'")
preparation['Equipment'] = normalize_text_column(preparation['Equipment'], EQUIPMENT_NORM_MAP)

# Ganti semua Diet dengan Tumpeng Gizi
print("\nMengganti semua data 'Diet' dengan standar Tumpeng Gizi")
preparation['Diet'] = preparation['Diet'].apply(replace_with_tumpeng_gizi)
# Out:
# Menormalisasi item individual di 'Exercises'
#
# Menormalisasi item individual di 'Equipment'
#
# Mengganti semua data 'Diet' dengan standar Tumpeng Gizi

# %%
print("\nContoh data 'preparation' setelah cleaning data:")

print(preparation.head())
# Out:
# Contoh data 'preparation' setelah cleaning data:
#   Hypertension Diabetes      Fitness Type        Level Fitness Goal   Sex  \
# 0           No       No  Muscular Fitness  Underweight  Weight Gain  Male
# 1          Yes       No    Cardio Fitness  Underweight  Weight Loss  Male
# 2           No      Yes  Muscular Fitness  Underweight  Weight Gain  Male
# 3          Yes      Yes  Muscular Fitness  Underweight  Weight Gain  Male
# 4           No       No  Muscular Fitness  Underweight  Weight Gain  Male
#
#   Age Group                                          Exercises  \
# 0     18-25  Squat, Deadlift, Bench Press, Overhead Presses...
# 1     18-25  Squat, Deadlift, Bench Press, Overhead Presses...
# 2     18-25  Squat, Yoga, Deadlift, Bench Press, Overhead P...
# 3     18-25  Squat, Yoga, Outdoor Cycling, Bench Press, Dea...
# 4     18-25  Squat, Deadlift, Bench Press, Overhead Presses...
#
#                                            Equipment  \
# 0  Dumbbell, Barbell, Flat Bench, Pull-Up Bar, Re...
# 1  Light Athletic Shoes, Resistance Band, Dumbbel...
# 2  Dumbbell, Barbell, Blood Glucose Monitor, Pull...
# 3  Light Athletic Shoes, Resistance Band, Dumbbel...
# 4  Dumbbell, Barbell, Flat Bench, Pull-Up Bar, Re...
#
#                                                 Diet
# 0  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 1  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 2  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 3  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 4  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...

# %%
# Buat Kolom 'content'
preparation['content'] = (
preparation['Exercises'].fillna('') + ' ' +
preparation['Equipment'].fillna('') + ' ' +
preparation['Diet'].fillna('')
).str.strip()

# %% [markdown]
# # TF IDF

# %%
# Hitung TF-IDF
tf = TfidfVectorizer(stop_words='english')

# Fit vectorizer ke data bersih
tfidf_matrix = tf.fit_transform(preparation['content'])
print(f"TF-IDF matrix shape: {tfidf_matrix.shape}")
# Out:
# TF-IDF matrix shape: (14589, 112)

# %%
# Visualisasi Perhitungan Dataframe TF IDF dengan Dense Matrix
tfidf_matrix_dense = tfidf_matrix.todense()

pd.DataFrame(
    tfidf_matrix_dense,
    columns=tf.get_feature_names_out(),
    index=preparation.index
).sample(22, axis=1).sample(10, axis=0)
# Out:
#           smith  setup       lat    rendah      apel  box    daging   protein  \
# 6176   0.000000    0.0  0.000000  0.094161  0.094161  0.0  0.094161  0.094161
# 5694   0.000000    0.0  0.000000  0.081685  0.081685  0.0  0.081685  0.081685
# 1232   0.000000    0.0  0.000000  0.067871  0.067871  0.0  0.067871  0.067871
# 2110   0.000000    0.0  0.000000  0.081685  0.081685  0.0  0.081685  0.081685
# 620    0.000000    0.0  0.000000  0.059907  0.059907  0.0  0.059907  0.059907
# 3574   0.000000    0.0  0.284166  0.060023  0.060023  0.0  0.060023  0.060023
# 11677  0.000000    0.0  0.000000  0.081685  0.081685  0.0  0.081685  0.081685
# 6429   0.000000    0.0  0.000000  0.079667  0.079667  0.0  0.079667  0.079667
# 2967   0.000000    0.0  0.000000  0.077013  0.077013  0.0  0.077013  0.077013
# 12499  0.245746    0.0  0.000000  0.061407  0.061407  0.0  0.061407  0.061407
#
#        stationary   running  ...      push  flat    crunch  swing  dumbbell  \
# 6176     0.230210  0.000000  ...  0.000000   0.0  0.000000    0.0  0.106096
# 5694     0.199708  0.183267  ...  0.000000   0.0  0.000000    0.0  0.000000
# 1232     0.000000  0.152274  ...  0.000000   0.0  0.000000    0.0  0.076474
# 2110     0.199708  0.183267  ...  0.000000   0.0  0.000000    0.0  0.000000
# 620      0.000000  0.000000  ...  0.000000   0.0  0.000000    0.0  0.067500
# 3574     0.000000  0.134666  ...  0.201355   0.0  0.000000    0.0  0.135263
# 11677    0.199708  0.183267  ...  0.000000   0.0  0.000000    0.0  0.000000
# 6429     0.194776  0.178740  ...  0.000000   0.0  0.000000    0.0  0.089766
# 2967     0.000000  0.000000  ...  0.000000   0.0  0.277437    0.0  0.086775
# 12499    0.000000  0.137772  ...  0.000000   0.0  0.000000    0.0  0.069191
#
#        ball      pull  extension   handles  deadlift
# 6176    0.0  0.000000        0.0  0.000000  0.000000
# 5694    0.0  0.000000        0.0  0.000000  0.000000
# 1232    0.0  0.000000        0.0  0.000000  0.000000
# 2110    0.0  0.000000        0.0  0.000000  0.000000
# 620     0.0  0.000000        0.0  0.265074  0.172079
# 3574    0.0  0.568332        0.0  0.000000  0.086206
# 11677   0.0  0.000000        0.0  0.000000  0.000000
# 6429    0.0  0.000000        0.0  0.000000  0.000000
# 2967    0.0  0.000000        0.0  0.000000  0.110609
# 12499   0.0  0.000000        0.0  0.000000  0.088195
#
# [10 rows x 22 columns]

# %% [markdown]
# # Cosine Similarity

# %%
# Menghitung Cosine Similarity Untuk Seluruh Item
cosine_sim = cosine_similarity(tfidf_matrix)

print(f"Cosine Similarity matrix shape: {cosine_sim.shape}")
# Out:
# Cosine Similarity matrix shape: (14589, 14589)

# %%
# Contoh Tampilan Cosine Sim Matrix
cosine_sim_df = pd.DataFrame(cosine_sim, index=preparation.index, columns=preparation.index)

print("\nContoh Cosine Similarity Matrix (5x5 sample):")
print(cosine_sim_df.sample(min(5, len(cosine_sim_df)), axis=1).sample(min(5, len(cosine_sim_df)), axis=0))
# Out:
# Contoh Cosine Similarity Matrix (5x5 sample):
#           10337     12157     575       9078      8176
# 1594   0.396336  0.862287  0.659180  0.502491  0.413841
# 3134   0.282507  0.834045  0.613944  0.339443  0.258650
# 8869   1.000000  0.334520  0.316795  0.420750  0.556401
# 10325  0.737078  0.490823  0.432022  0.414485  0.386925
# 6445   0.438437  0.268935  0.254685  0.292671  0.323338

# %%
# Menganalisis item unik dari dataframe 'preparation'

# Untuk Exercises
all_exercises = set()

for item_list in preparation['Exercises'].apply(lambda x: clean_items(x, EXERCISE_NORM_MAP)):
    all_exercises.update(item_list)

print("Unique Exercises")
print(sorted(list(all_exercises)))
print(f"Total unique exercises: {len(all_exercises)}")


# Untuk Equipment
all_equipment = set()

for item_list in preparation['Equipment'].apply(lambda x: clean_items(x, EQUIPMENT_NORM_MAP)):
    all_equipment.update(item_list)

print("\nUnique Equipment")
print(sorted(list(all_equipment)))
print(f"Total unique equipment: {len(all_equipment)}")
# Out:
# Unique Exercises
# ['Aqua Jogging', 'Assisted Lat Pull-Down', 'Assisted Pull-Up', 'Band Row', 'Barbell Back Squat', 'Bench Press', 'Brisk Walking', 'Cable Row', 'Cardio Dance', 'Chair Squat', 'Chest Press', 'Deadlift', 'Dumbbell Row', 'Dumbbell Squat', 'Elliptical', 'Farmers Walk', 'Front Plank', 'Goblet Squat', 'Hip Bridge', 'Hip Hinge', 'Kettlebell Swing', 'Lat Pull-Down', 'Leg Curl', 'Leg Extension', 'Leg Press', 'Lunges', 'Outdoor Cycling', 'Overhead Presses', 'Plank', 'Pull-Up', 'Push Up', 'Resistance Band Row', 'Reverse Crunch', 'Romanian Deadlift', 'Running', 'Russian Twist', 'Seated Cable Row', 'Seated Row', 'Side Plank', 'Squat', 'Stair Climber', 'Stationary Bike', 'Swimming', 'Treadmill', 'Walking', 'Wall Plank', 'Wall Squat', 'Yoga']
# Total unique exercises: 48
#
# Unique Equipment
# ['Assisted Pull-Up Machine', 'Barbell', 'Bench', 'Blood Glucose Monitor', 'Box', 'Cable Row Machine', 'Chest Press Machine', 'Dumbbell', 'Ellipticals Machine', 'Farmer Walk Handles', 'Flat Bench', 'Incline Bench', 'Incline Press Machine', 'Indoor Rowers', 'Kettlebell', 'Lat Pull-Down Machine', 'Leg Curl Machine', 'Leg Extension Machine', 'Leg Press Machine', 'Light Athletic Shoes', 'Medicine Ball', 'Plank Setup', 'Pull-Up Bar', 'Resistance Band', 'Rowing Machine', 'Seated Row Machine', 'Smith Machine', 'Squat Rack', 'Strap', 'Treadmill', 'Treadmill Machine', 'Yoga Mat']
# Total unique equipment: 32

# %% [markdown]
# # Fungsi Content Based Filtering (CBF)

# %%
# Fungsi Rekomendasi CBF (Logika Cosine Sim + Modus)

# Memberikan rekomendasi CBF: Filter -> Cari Top N Mirip -> Voting Modus.
def cbf_recommendations_with_cosine(fitness_type, hypertension, diabetes, level, goal, sex, age_group, top_n_similar=5):

    global preparation, cosine_sim
    if 'preparation' not in globals() or 'cosine_sim' not in globals():
         return {"Error": "Data 'preparation' atau 'cosine_sim' belum dihitung."}

    hypertension_clean = str(hypertension).strip().title()
    diabetes_clean = str(diabetes).strip().title()
    level_clean = str(level).strip().title()
    goal_clean = str(goal).strip().title()
    sex_clean = str(sex).strip().title()
    age_group_clean = str(age_group).strip()
    print(f"\n Mencari filter spesifik...")

    # Base query (Kondisi Kesehatan + Tipe Fitness)
    base_query = (preparation['Fitness Type'] == fitness_type) & \
                 (preparation['Hypertension'].str.strip().str.title() == hypertension_clean) & \
                 (preparation['Diabetes'].str.strip().str.title() == diabetes_clean)

    print(f"   - Mencoba: Age Group, Level, Goal, Sex...")

    # Filter Spesifik
    filtered_df = preparation[
        base_query &
        (preparation['Age Group'].str.strip() == age_group_clean) &
        (preparation['Level'].str.strip().str.title() == level_clean) &
        (preparation['Fitness Goal'].str.strip().str.title() == goal_clean) &
        (preparation['Sex'].str.strip().str.title() == sex_clean)
    ].copy()

    # Fallback: Buang 'Age Group'
    if filtered_df.empty:
        print(f"   - Gagal. Fallback: Mencoba tanpa 'Age Group'...")
        filtered_df = preparation[
            base_query &
            (preparation['Level'].str.strip().str.title() == level_clean) &
            (preparation['Fitness Goal'].str.strip().str.title() == goal_clean) &
            (preparation['Sex'].str.strip().str.title() == sex_clean)
        ].copy()

    # Fallback: Buang 'Sex'
    if filtered_df.empty:
        print(f"   - Gagal. Fallback: Mencoba tanpa 'Sex' & 'Age Group'...")
        filtered_df = preparation[
            base_query &
            (preparation['Level'].str.strip().str.title() == level_clean) &
            (preparation['Fitness Goal'].str.strip().str.title() == goal_clean)
        ].copy()

    # Fallback: Buang 'Level' & 'Goal'
    if filtered_df.empty:
        print(f"   - Gagal. Fallback: Mencoba tanpa 'Level' & 'Goal'...")
        filtered_df = preparation[base_query].copy()

    # Fallback: Cuma 'Fitness Type'
    if filtered_df.empty:
        print(f"   - Gagal. Fallback: Mencoba HANYA 'Fitness Type'...")
        filtered_df = preparation[preparation['Fitness Type'] == fitness_type].copy()
        if filtered_df.empty:
            return {"Error": f"Tidak ada data untuk Tipe Fitness: {fitness_type}."}

    if len(filtered_df) < top_n_similar:
        print(f"Warning: Hanya ditemukan {len(filtered_df)} data cocok, kurang dari top_n={top_n_similar}.")
        top_n_similar = len(filtered_df)

    if len(filtered_df) == 0:
         return {"Error": "Tidak ada data cocok sama sekali."}

    # Hitung rata-rata similarity score dan ambil 5 tertinggi

    # Ambil index data yang lolos filter
    filtered_indices = filtered_df.index.tolist()

    # Slice matrix cosine similarity hanya untuk data yang lolos filter
    sim_matrix_filtered = cosine_sim[filtered_indices, :][:, filtered_indices]

    # Hitung rata-rata similarity
    avg_sim_scores = sim_matrix_filtered.mean(axis=1)
    sim_scores_series = pd.Series(avg_sim_scores, index=filtered_indices)

    # Ambil Top N (default 5) dengan score tertinggi
    top_n_indices = sim_scores_series.nlargest(top_n_similar).index.tolist()
    topN_df = preparation.loc[top_n_indices]

    print(f"\nTop {top_n_similar} item paling mirip (berdasarkan konten):")
    print(topN_df[['Exercises', 'Equipment', 'Diet']])

    try:
      # Mengambil nilai modus (yang paling sering muncul) dari 5 kandidat teratas
        final_exercise = topN_df['Exercises'].mode()[0]
        final_equipment = topN_df['Equipment'].mode()[0]
        final_diet = topN_df['Diet'].mode()[0]
    except Exception as e: return {"Error": f"Gagal voting: {e}"}

    return {'Exercises': final_exercise, 'Equipment': final_equipment, 'Diet': final_diet}

# %%
# CONTOH TEST (UNDERWEIGHT)
print("\nContoh hasil rekomendasi CBF:")
recommendations_cosine = cbf_recommendations_with_cosine(
  fitness_type="Muscular Fitness",
  hypertension="No",
  diabetes="No",
  level="Underweight",
  goal="Weight Gain",
  sex="Female",
  age_group="26-35",
  top_n_similar=5
  )

print("\nHasil Rekomendasi:")
print(recommendations_cosine)
# Out:
# Contoh hasil rekomendasi CBF:
#
#  Mencari filter spesifik...
#    - Mencoba: Age Group, Level, Goal, Sex...
#
# Top 5 item paling mirip (berdasarkan konten):
#                                               Exercises  \
# 1572  Squat, Deadlift, Bench Press, Overhead Presses...
# 1605  Squat, Deadlift, Bench Press, Overhead Presses...
# 1637  Squat, Deadlift, Bench Press, Overhead Presses...
# 1669  Squat, Deadlift, Bench Press, Overhead Presses...
# 1701  Squat, Deadlift, Bench Press, Overhead Presses...
#
#                                               Equipment  \
# 1572  Dumbbell, Barbell, Flat Bench, Pull-Up Bar, Re...
# 1605  Dumbbell, Barbell, Flat Bench, Pull-Up Bar, Re...
# 1637  Dumbbell, Barbell, Flat Bench, Pull-Up Bar, Re...
# 1669  Dumbbell, Barbell, Flat Bench, Pull-Up Bar, Re...
# 1701  Dumbbell, Barbell, Flat Bench, Pull-Up Bar, Re...
#
#                                                    Diet
# 1572  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 1605  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 1637  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 1669  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 1701  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
#
# Hasil Rekomendasi:
# {'Exercises': 'Squat, Deadlift, Bench Press, Overhead Presses, Push Up, Kettlebell Swing, Pull-Up, Lat Pull-Down, Plank, Side Plank', 'Equipment': 'Dumbbell, Barbell, Flat Bench, Pull-Up Bar, Resistance Band, Kettlebell, Yoga Mat', 'Diet': 'Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagung, Singkong, Ubi); Mineral & Serat: (Bayam, Kangkung, Wortel, Tomat, Brokoli, Jeruk, Apel, Pisang, Pepaya); Protein: (Tahu, Tempe, Kacang-kacangan, Ikan, Ayam Tanpa Kulit, Telur, Daging Tanpa Lemak, Susu Rendah Lemak)'}

# %%
# CONTOH TEST (OVERWEIGHT)
print("\nContoh hasil rekomendasi CBF:")
recommendations_cosine = cbf_recommendations_with_cosine(
  fitness_type="Cardio Fitness",
  hypertension="No",
  diabetes="No",
  level="Overweight",
  goal="Weight Loss",
  sex="Male",
  age_group="26-35",
  top_n_similar=5
  )

print("\nHasil Rekomendasi:")
print(recommendations_cosine)
# Out:
# Contoh hasil rekomendasi CBF:
#
#  Mencari filter spesifik...
#    - Mencoba: Age Group, Level, Goal, Sex...
#
# Top 5 item paling mirip (berdasarkan konten):
#                                               Exercises  \
# 336   Brisk Walking, Outdoor Cycling, Swimming, Runn...
# 404   Brisk Walking, Outdoor Cycling, Swimming, Runn...
# 1649  Brisk Walking, Outdoor Cycling, Swimming, Runn...
# 1681  Brisk Walking, Outdoor Cycling, Swimming, Runn...
# 1713  Brisk Walking, Outdoor Cycling, Swimming, Runn...
#
#                                               Equipment  \
# 336   Ellipticals Machine, Indoor Rowers, Treadmill ...
# 404   Ellipticals Machine, Indoor Rowers, Treadmill ...
# 1649  Ellipticals Machine, Indoor Rowers, Treadmill ...
# 1681  Ellipticals Machine, Indoor Rowers, Treadmill ...
# 1713  Ellipticals Machine, Indoor Rowers, Treadmill ...
#
#                                                    Diet
# 336   Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 404   Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 1649  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 1681  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 1713  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
#
# Hasil Rekomendasi:
# {'Exercises': 'Brisk Walking, Outdoor Cycling, Swimming, Running, Cardio Dance, Barbell Back Squat, Goblet Squat, Bench Press, Deadlift, Kettlebell Swing, Lat Pull-Down, Assisted Pull-Up, Plank, Side Plank', 'Equipment': 'Ellipticals Machine, Indoor Rowers, Treadmill machine, Rowing Machine, Barbell, Dumbbell, Flat Bench, Incline Bench, Lat Pull-Down Machine, Yoga Mat, Kettlebell', 'Diet': 'Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagung, Singkong, Ubi); Mineral & Serat: (Bayam, Kangkung, Wortel, Tomat, Brokoli, Jeruk, Apel, Pisang, Pepaya); Protein: (Tahu, Tempe, Kacang-kacangan, Ikan, Ayam Tanpa Kulit, Telur, Daging Tanpa Lemak, Susu Rendah Lemak)'}

# %%
# CONTOH TEST (OVERWEIGHT + WEIGHT GAIN)
print("\nContoh hasil rekomendasi CBF:")
recommendations_cosine = cbf_recommendations_with_cosine(
  fitness_type="Muscular Fitness",
  hypertension="No",
  diabetes="No",
  level="Overweight",
  goal="Weight Gain",
  sex="Female",
  age_group="26-35",
  top_n_similar=5
  )

print("\nHasil Rekomendasi:")
print(recommendations_cosine)
# Out:
# Contoh hasil rekomendasi CBF:
#
#  Mencari filter spesifik...
#    - Mencoba: Age Group, Level, Goal, Sex...
#    - Gagal. Fallback: Mencoba tanpa 'Age Group'...
#    - Gagal. Fallback: Mencoba tanpa 'Sex' & 'Age Group'...
#    - Gagal. Fallback: Mencoba tanpa 'Level' & 'Goal'...
#
# Top 5 item paling mirip (berdasarkan konten):
#                                              Exercises  \
# 416  Squat, Deadlift, Bench Press, Overhead Presses...
# 420  Squat, Deadlift, Bench Press, Overhead Presses...
# 448  Squat, Deadlift, Bench Press, Overhead Presses...
# 452  Squat, Deadlift, Bench Press, Overhead Presses...
# 480  Squat, Deadlift, Bench Press, Overhead Presses...
#
#                                              Equipment  \
# 416  Dumbbell, Barbell, Bench, Cable Row Machine, K...
# 420  Dumbbell, Barbell, Bench, Cable Row Machine, K...
# 448  Dumbbell, Barbell, Bench, Cable Row Machine, K...
# 452  Dumbbell, Barbell, Bench, Cable Row Machine, K...
# 480  Dumbbell, Barbell, Bench, Cable Row Machine, K...
#
#                                                   Diet
# 416  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 420  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 448  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 452  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 480  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
#
# Hasil Rekomendasi:
# {'Exercises': 'Squat, Deadlift, Bench Press, Overhead Presses, Goblet Squat, Chest Press, Romanian Deadlift, Seated Row, Farmers Walk', 'Equipment': 'Dumbbell, Barbell, Bench, Cable Row Machine, Kettlebell', 'Diet': 'Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagung, Singkong, Ubi); Mineral & Serat: (Bayam, Kangkung, Wortel, Tomat, Brokoli, Jeruk, Apel, Pisang, Pepaya); Protein: (Tahu, Tempe, Kacang-kacangan, Ikan, Ayam Tanpa Kulit, Telur, Daging Tanpa Lemak, Susu Rendah Lemak)'}

# %%
# CONTOH TEST (UNDERWEIGHT + WEIGHT LOSS)
print("\nContoh hasil rekomendasi CBF:")
recommendations_cosine = cbf_recommendations_with_cosine(
  fitness_type="Cardio Fitness",
  hypertension="No",
  diabetes="No",
  level="Underweight",
  goal="Weight Loss",
  sex="Female",
  age_group="26-35",
  top_n_similar=5
  )

print("\nHasil Rekomendasi:")
print(recommendations_cosine)
# Out:
# Contoh hasil rekomendasi CBF:
#
#  Mencari filter spesifik...
#    - Mencoba: Age Group, Level, Goal, Sex...
#    - Gagal. Fallback: Mencoba tanpa 'Age Group'...
#    - Gagal. Fallback: Mencoba tanpa 'Sex' & 'Age Group'...
#    - Gagal. Fallback: Mencoba tanpa 'Level' & 'Goal'...
#
# Top 5 item paling mirip (berdasarkan konten):
#                                              Exercises  \
# 432  Brisk Walking, Outdoor Cycling, Swimming, Runn...
# 436  Brisk Walking, Outdoor Cycling, Swimming, Runn...
# 464  Brisk Walking, Outdoor Cycling, Swimming, Runn...
# 468  Brisk Walking, Outdoor Cycling, Swimming, Runn...
# 496  Brisk Walking, Outdoor Cycling, Swimming, Runn...
#
#                                              Equipment  \
# 432  Ellipticals Machine, Indoor Rowers, Treadmill ...
# 436  Ellipticals Machine, Indoor Rowers, Treadmill ...
# 464  Ellipticals Machine, Indoor Rowers, Treadmill ...
# 468  Ellipticals Machine, Indoor Rowers, Treadmill ...
# 496  Ellipticals Machine, Indoor Rowers, Treadmill ...
#
#                                                   Diet
# 432  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 436  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 464  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 468  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 496  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
#
# Hasil Rekomendasi:
# {'Exercises': 'Brisk Walking, Outdoor Cycling, Swimming, Running, Cardio Dance, Leg Press, Chest Press, Romanian Deadlift, Seated Cable Row, Farmers Walk', 'Equipment': 'Ellipticals Machine, Indoor Rowers, Treadmill machine, Rowing Machine, Leg Press Machine, Dumbbell, Barbell, Smith Machine, Cable Row Machine, Resistance Band', 'Diet': 'Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagung, Singkong, Ubi); Mineral & Serat: (Bayam, Kangkung, Wortel, Tomat, Brokoli, Jeruk, Apel, Pisang, Pepaya); Protein: (Tahu, Tempe, Kacang-kacangan, Ikan, Ayam Tanpa Kulit, Telur, Daging Tanpa Lemak, Susu Rendah Lemak)'}

# %%
# CONTOH TEST (NORMAL + WEIGHT LOSS)
print("\nContoh hasil rekomendasi CBF:")
recommendations_cosine = cbf_recommendations_with_cosine(
  fitness_type="Cardio Fitness",
  hypertension="No",
  diabetes="No",
  level="Normal",
  goal="Weight Loss",
  sex="Female",
  age_group="26-35",
  top_n_similar=5
  )

print("\nHasil Rekomendasi:")
print(recommendations_cosine)
# Out:
# Contoh hasil rekomendasi CBF:
#
#  Mencari filter spesifik...
#    - Mencoba: Age Group, Level, Goal, Sex...
#
# Top 5 item paling mirip (berdasarkan konten):
#                                               Exercises  \
# 2669  Squat, Deadlift, Bench Press, Overhead Presses...
# 2733  Squat, Deadlift, Bench Press, Overhead Presses...
# 3853  Squat, Deadlift, Bench Press, Overhead Presses...
# 3917  Squat, Deadlift, Bench Press, Overhead Presses...
# 3949  Squat, Deadlift, Bench Press, Overhead Presses...
#
#                                               Equipment  \
# 2669  Dumbbell, Barbell, Squat Rack, Cable Row Machi...
# 2733  Dumbbell, Barbell, Squat Rack, Cable Row Machi...
# 3853  Dumbbell, Barbell, Squat Rack, Cable Row Machi...
# 3917  Dumbbell, Barbell, Squat Rack, Cable Row Machi...
# 3949  Dumbbell, Barbell, Squat Rack, Cable Row Machi...
#
#                                                    Diet
# 2669  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 2733  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 3853  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 3917  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 3949  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
#
# Hasil Rekomendasi:
# {'Exercises': 'Squat, Deadlift, Bench Press, Overhead Presses, Goblet Squat, Barbell Back Squat, Chest Press, Romanian Deadlift, Seated Cable Row, Farmers Walk', 'Equipment': 'Dumbbell, Barbell, Squat Rack, Cable Row Machine, Kettlebell, Farmer Walk Handles', 'Diet': 'Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagung, Singkong, Ubi); Mineral & Serat: (Bayam, Kangkung, Wortel, Tomat, Brokoli, Jeruk, Apel, Pisang, Pepaya); Protein: (Tahu, Tempe, Kacang-kacangan, Ikan, Ayam Tanpa Kulit, Telur, Daging Tanpa Lemak, Susu Rendah Lemak)'}

# %% [markdown]
# # Evaluasi Content Based Filtering

# %%
# Evaluasi CBF dengan Precision@k & Recall@k

def calculate_average_metrics_at_k(k_values, n_samples=None):

    global preparation, cosine_sim, EXERCISE_NORM_MAP, EQUIPMENT_NORM_MAP

    if 'preparation' not in globals() or 'cosine_sim' not in globals():
         print("ERROR: Data 'preparation' atau 'cosine_sim' belum dihitung.")
         return {}, {}
    if 'EXERCISE_NORM_MAP' not in globals() or 'EQUIPMENT_NORM_MAP' not in globals():
         print("ERROR: Normalization maps (EXERCISE_NORM_MAP / EQUIPMENT_NORM_MAP) tidak ditemukan.")
         return {}, {}

    results_precision = {k: [] for k in k_values}
    results_recall = {k: [] for k in k_values}

    if n_samples and n_samples < len(preparation):
        eval_indices = preparation.sample(n_samples, random_state=42).index
        print(f"Mengevaluasi {n_samples} sampel data...")
    else:
        eval_indices = preparation.index
        print(f"Mengevaluasi semua {len(preparation)} data...")

    for i in eval_indices:
        try:
            gt_exercises = set(clean_items(preparation.loc[i, 'Exercises'], EXERCISE_NORM_MAP))
            gt_equipment = set(clean_items(preparation.loc[i, 'Equipment'], EQUIPMENT_NORM_MAP))
            ground_truth_items = gt_exercises.union(gt_equipment)
            if not ground_truth_items: continue
        except Exception as e:
            print(f"Warning: Gagal memproses ground truth baris {i}: {e}")
            continue

        current_ft = preparation.loc[i, 'Fitness Type']
        current_h_clean = str(preparation.loc[i, 'Hypertension']).strip().title()
        current_d_clean = str(preparation.loc[i, 'Diabetes']).strip().title()
        current_level_clean = str(preparation.loc[i, 'Level']).strip().title()
        current_goal_clean = str(preparation.loc[i, 'Fitness Goal']).strip().title()
        current_sex_clean = str(preparation.loc[i, 'Sex']).strip().title()
        current_age_group_clean = str(preparation.loc[i, 'Age Group']).strip()

        base_query = (preparation['Fitness Type'] == current_ft) & \
                     (preparation['Hypertension'].str.strip().str.title() == current_h_clean) & \
                     (preparation['Diabetes'].str.strip().str.title() == current_d_clean)

        # Coba Paling Spesifik
        filtered_df = preparation[
            base_query &
            (preparation['Age Group'].str.strip() == current_age_group_clean) &
            (preparation['Level'].str.strip().str.title() == current_level_clean) &
            (preparation['Fitness Goal'].str.strip().str.title() == current_goal_clean) &
            (preparation['Sex'].str.strip().str.title() == current_sex_clean)
        ].copy()

        # Fallback: Buang 'Age Group'
        if len(filtered_df) <= 1:
            filtered_df = preparation[
                base_query &
                (preparation['Level'].str.strip().str.title() == current_level_clean) &
                (preparation['Fitness Goal'].str.strip().str.title() == current_goal_clean) &
                (preparation['Sex'].str.strip().str.title() == current_sex_clean)
            ].copy()

        # Fallback: Buang 'Sex'
        if len(filtered_df) <= 1:
            filtered_df = preparation[
                base_query &
                (preparation['Level'].str.strip().str.title() == current_level_clean) &
                (preparation['Fitness Goal'].str.strip().str.title() == current_goal_clean)
            ].copy()

        # Fallback: Buang 'Level' & 'Goal'
        if len(filtered_df) <= 1:
            filtered_df = preparation[base_query].copy()

        # Fallback: Cuma 'Fitness Type'
        if len(filtered_df) <= 1:
            filtered_df = preparation[preparation['Fitness Type'] == current_ft].copy()

        if len(filtered_df) <= 1:
            continue

        filtered_indices = filtered_df.index.tolist()
        try:
            idx_in_filtered = filtered_indices.index(i)
        except ValueError:
            continue

        # top-k
        sim_scores_row = cosine_sim[filtered_indices, :][:, filtered_indices][idx_in_filtered]
        sim_series = pd.Series(sim_scores_row, index=filtered_indices).sort_values(ascending=False)

        for k in k_values:
            top_k_indices = sim_series[1:k+1].index.tolist()
            if not top_k_indices:
                 precision_at_k = 0.0
                 recall_at_k = 0.0
            else:
                recommended_items = set()
                top_k_df = preparation.loc[top_k_indices]
                combined_ex = ' | '.join(top_k_df['Exercises'].astype(str).tolist())
                combined_eq = ' | '.join(top_k_df['Equipment'].astype(str).tolist())

                recommended_items.update(clean_items(combined_ex, EXERCISE_NORM_MAP))
                recommended_items.update(clean_items(combined_eq, EQUIPMENT_NORM_MAP))

                hits = ground_truth_items.intersection(recommended_items)

                if len(recommended_items) == 0:
                    precision_at_k = 0.0
                else:
                    precision_at_k = len(hits) / len(recommended_items)

                recall_at_k = len(hits) / len(ground_truth_items)

            results_precision[k].append(precision_at_k)
            results_recall[k].append(recall_at_k)

    # Kalkulasi rata-rata
    avg_precision = {k: np.mean(v) if v else 0.0 for k, v in results_precision.items()}
    avg_recall = {k: np.mean(v) if v else 0.0 for k, v in results_recall.items()}

    return avg_precision, avg_recall

#  Evaluasi Precision@k
k_to_evaluate = [5, 10]

# Ambil dua value
avg_precision, avg_recall = calculate_average_metrics_at_k(k_values=k_to_evaluate, n_samples=100)

print("\nHasil Rata-rata Precision & Recall @k")

for k in k_to_evaluate:
  print(f"Precision@{k}: {avg_precision.get(k, 0.0):.4f}")
  print(f"Recall@{k}   : {avg_recall.get(k, 0.0):.4f}")
# Out:
# Mengevaluasi 100 sampel data...
#
# Hasil Rata-rata Precision & Recall @k
# Precision@5: 0.9856
# Recall@5   : 0.9971
# Precision@10: 0.9740
# Recall@10   : 0.9971

# %% [markdown]
# # Menyimpan Model

# %%
import os

output_folder = "models"
if not os.path.exists(output_folder):
  os.makedirs(output_folder)
  print(f"- Membuat folder '{output_folder}'.")

# Menyimpan model KNN dengan parameter terbaik
best_k = 7
knn_final = KNeighborsClassifier(n_neighbors=best_k)
knn_final.fit(X_train, y_train)

# Simpan KNN components
joblib.dump(knn_final, os.path.join(output_folder, "knn_model.pkl"))
joblib.dump(le_dict, os.path.join(output_folder, "label_encoders.pkl"))
joblib.dump(le_target, os.path.join(output_folder, "target_encoder.pkl"))
joblib.dump(scaler, os.path.join(output_folder, "scaler.pkl"))

# Simpan data 'preparation'
joblib.dump(preparation, os.path.join(output_folder, "preparation_data.pkl"))

# Simpan TF-IDF & Cosine Sim
joblib.dump(tf, os.path.join(output_folder, "tfidf_vectorizer.pkl"))
joblib.dump(cosine_sim, os.path.join(output_folder, "cosine_sim_matrix.pkl"))
# Out:
# ['models/cosine_sim_matrix.pkl']

# %% [markdown]
# # Inference

# %%
# Mendefinisikan fungsi untuk inference

def calculate_bmi(height_cm, weight_kg):
    if height_cm == 0: return 0
    height_m = height_cm / 100.0
    return weight_kg / (height_m ** 2)

def get_bmi_level(bmi):
    if bmi < 18.5: return "Underweight"
    elif 18.5 <= bmi < 24.9: return "Normal"
    elif 25.0 <= bmi < 29.9: return "Overweight"
    else: return "Obese"

def get_fitness_goal(level):
    if level in ["Underweight", "Normal"]: return "Weight Gain"
    elif level in ["Overweight", "Obese"]: return "Weight Loss"
    return None

def get_age_group(age):
    if 18 <= age <= 25: return "18-25"
    elif 26 <= age <= 35: return "26-35"
    elif 36 <= age <= 45: return "36-45"
    elif 46 <= age <= 55: return "46-55"
    else: return "56+"

def knn_predict_fitness_test(user_input_dict, model_folder="models"):
    try:
        knn_model = joblib.load(os.path.join(model_folder, "knn_model.pkl"))
        scaler = joblib.load(os.path.join(model_folder, "scaler.pkl"))
        le_dict = joblib.load(os.path.join(model_folder, "label_encoders.pkl"))
        le_target = joblib.load(os.path.join(model_folder, "target_encoder.pkl"))
        categorical_cols = ['Sex', 'Level', 'Fitness Goal', 'Age Group']
        numeric_cols = ['Age', 'Height', 'Weight', 'BMI']
    except FileNotFoundError: return "Error: File model KNN tidak ditemukan"
    ordered_cols = ['Sex', 'Age', 'Height', 'Weight', 'BMI', 'Level', 'Fitness Goal', 'Age Group']
    new_user = pd.DataFrame([user_input_dict])
    try:
        for col in categorical_cols:
            new_user.loc[:, col] = le_dict[col].transform(new_user[col])
    except Exception as e: return f"Error encoding: {e}."
    with warnings.catch_warnings():
        warnings.simplefilter("ignore", category=FutureWarning)
        new_user.loc[:, numeric_cols] = scaler.transform(new_user[numeric_cols])
    new_user = new_user[ordered_cols]
    pred_class = knn_model.predict(new_user)[0]
    return le_target.inverse_transform([pred_class])[0]

def cbf_recommendations_with_cosine_test(fitness_type, hypertension, diabetes, level, goal, sex, age_group, top_n_similar=5, model_folder="models"):
    try:
        preparation_loaded = joblib.load(os.path.join(model_folder, "preparation_data.pkl"))
        cosine_sim_loaded = joblib.load(os.path.join(model_folder, "cosine_sim_matrix.pkl"))
    except FileNotFoundError:
        return {"Error": "File model (preparation/cosine_sim) tidak ditemukan"}

    hypertension_clean = str(hypertension).strip().title()
    diabetes_clean = str(diabetes).strip().title()
    level_clean = str(level).strip().title()
    goal_clean = str(goal).strip().title()
    sex_clean = str(sex).strip().title()
    age_group_clean = str(age_group).strip()

    print(f"\n Mencari filter spesifik...")

    base_query = (preparation_loaded['Fitness Type'] == fitness_type) & \
                 (preparation_loaded['Hypertension'].str.strip().str.title() == hypertension_clean) & \
                 (preparation_loaded['Diabetes'].str.strip().str.title() == diabetes_clean)

    # Langkah-langkah sistem rekomendasi
    # Coba Paling Spesifik (Lengkap)
    print(f"   - Mencoba: Age Group, Level, Goal, Sex...")
    filtered_df = preparation_loaded[
        base_query &
        (preparation_loaded['Age Group'].str.strip() == age_group_clean) &
        (preparation_loaded['Level'].str.strip().str.title() == level_clean) &
        (preparation_loaded['Fitness Goal'].str.strip().str.title() == goal_clean) &
        (preparation_loaded['Sex'].str.strip().str.title() == sex_clean)
    ].copy()

    # Fallback: Buang 'Age Group'
    if filtered_df.empty:
        print(f"   - Gagal. Fallback: Mencoba tanpa 'Age Group'...")
        filtered_df = preparation_loaded[
            base_query &
            (preparation_loaded['Level'].str.strip().str.title() == level_clean) &
            (preparation_loaded['Fitness Goal'].str.strip().str.title() == goal_clean) &
            (preparation_loaded['Sex'].str.strip().str.title() == sex_clean)
        ].copy()

    # Fallback: Buang 'Sex'
    if filtered_df.empty:
        print(f"   - Gagal. Fallback: Mencoba tanpa 'Sex' & 'Age Group'...")
        filtered_df = preparation_loaded[
            base_query &
            (preparation_loaded['Level'].str.strip().str.title() == level_clean) &
            (preparation_loaded['Fitness Goal'].str.strip().str.title() == goal_clean)
        ].copy()

    # Fallback: Buang 'Level' & 'Goal'
    if filtered_df.empty:
        print(f"   - Gagal. Fallback: Mencoba tanpa 'Level' & 'Goal'...")
        filtered_df = preparation_loaded[base_query].copy()

    # Fallback: Cuma 'Fitness Type'
    if filtered_df.empty:
        print(f"   - Gagal. Fallback: Mencoba HANYA 'Fitness Type'...")
        filtered_df = preparation_loaded[preparation_loaded['Fitness Type'] == fitness_type].copy()
        if filtered_df.empty:
            return {"Error": f"Tidak ada data untuk Tipe Fitness: {fitness_type}."}

    if len(filtered_df) < top_n_similar:
        print(f"\nWarning: Hanya ditemukan {len(filtered_df)} data cocok, kurang dari top_n={top_n_similar}.")
        top_n_similar = len(filtered_df)

    if len(filtered_df) == 0:
        return {"Error": "Tidak ada data cocok sama sekali."}

    filtered_indices = filtered_df.index.tolist()
    sim_matrix_filtered = cosine_sim_loaded[filtered_indices, :][:, filtered_indices]
    avg_sim_scores = sim_matrix_filtered.mean(axis=1)
    sim_scores_series = pd.Series(avg_sim_scores, index=filtered_indices)
    top_n_indices = sim_scores_series.nlargest(top_n_similar).index.tolist()
    topN_df = preparation_loaded.loc[top_n_indices]

    print(f"\nTop {top_n_similar} item paling mirip (berdasarkan konten):")
    print(topN_df[['Exercises', 'Equipment', 'Diet']])

    try:
        final_exercise = topN_df['Exercises'].mode()[0]
        final_equipment = topN_df['Equipment'].mode()[0]
        final_diet = topN_df['Diet'].mode()[0]
    except Exception as e:
        return {"Error": f"Gagal voting: {e}"}

    return {'Exercises': final_exercise, 'Equipment': final_equipment, 'Diet': final_diet}


def get_full_recommendation_test_cosine(sex, age, height_cm, weight_kg, hypertension, diabetes):
    print("1. Menerima Input Mentah")
    print(f"   Sex: {sex}, Age: {age}, Height: {height_cm}cm, Weight: {weight_kg}kg")
    print(f"   Hypertension: {hypertension}, Diabetes: {diabetes}")
    bmi = calculate_bmi(height_cm, weight_kg)
    print(f"\n2. Kalkulasi Turunan")
    print(f"   Calculated BMI: {bmi:.2f}")
    level = get_bmi_level(bmi)
    print(f"   Determined Level: {level}")
    goal = get_fitness_goal(level)
    print(f"   DetermGmbined Fitness Goal: {goal}")
    age_group = get_age_group(age)
    print(f"   Determined Age Group: {age_group}")

    knn_input = {"Sex": sex, "Age": age, "Height": height_cm, "Weight": weight_kg, "BMI": bmi, "Level": level, "Fitness Goal": goal, "Age Group": age_group} # <-- TAMBAH 'Age Group'
    print(f"\n3. Prediksi KNN (Fitness Type)")
    predicted_type = knn_predict_fitness_test(knn_input)
    if "Error" in str(predicted_type):
        print(f"   Error KNN: {predicted_type}")
        return
    print(f"   Predicted Fitness Type: {predicted_type}")
    print(f"\n4. Rekomendasi Detail (CBF dengan Cosine Sim)")

    cbf_result = cbf_recommendations_with_cosine_test(
        fitness_type=predicted_type,
        hypertension=hypertension,
        diabetes=diabetes,
        level=level,
        goal=goal,
        sex=sex,
        age_group=age_group,
        top_n_similar=5
    )
    print(f"\nHASIL REKOMENDASI FINAL")
    print(f"Level: {level} (Goal: {goal}) (Age: {age_group})")
    print(f"Tipe Fitness: {predicted_type}")
    print("---------------------------------")
    print(f"Exercises: {cbf_result.get('Exercises', 'N/A')}")
    print(f"Equipment: {cbf_result.get('Equipment', 'N/A')}")
    print(f"Diet: {cbf_result.get('Diet', 'N/A')}")

# %%
# Contoh Inference

print("CONTOH 1 (OVERWEIGHT)")
get_full_recommendation_test_cosine(sex="Male", age=25, height_cm=170, weight_kg=75, hypertension="No", diabetes="No")
# Out:
# CONTOH 1 (OVERWEIGHT)
# 1. Menerima Input Mentah
#    Sex: Male, Age: 25, Height: 170cm, Weight: 75kg
#    Hypertension: No, Diabetes: No
#
# 2. Kalkulasi Turunan
#    Calculated BMI: 25.95
#    Determined Level: Overweight
#    DetermGmbined Fitness Goal: Weight Loss
#    Determined Age Group: 18-25
#
# 3. Prediksi KNN (Fitness Type)
#    Predicted Fitness Type: Cardio Fitness
#
# 4. Rekomendasi Detail (CBF dengan Cosine Sim)
#
#  Mencari filter spesifik...
#    - Mencoba: Age Group, Level, Goal, Sex...
#
# Top 5 item paling mirip (berdasarkan konten):
#                                             Exercises  \
# 16  Brisk Walking, Outdoor Cycling, Swimming, Runn...
# 48  Brisk Walking, Outdoor Cycling, Swimming, Runn...
# 52  Brisk Walking, Outdoor Cycling, Swimming, Runn...
# 80  Brisk Walking, Outdoor Cycling, Swimming, Runn...
# 84  Brisk Walking, Outdoor Cycling, Swimming, Runn...
#
#                                             Equipment  \
# 16  Ellipticals Machine, Indoor Rowers, Treadmill ...
# 48  Ellipticals Machine, Indoor Rowers, Treadmill ...
# 52  Ellipticals Machine, Indoor Rowers, Treadmill ...
# 80  Ellipticals Machine, Indoor Rowers, Treadmill ...
# 84  Ellipticals Machine, Indoor Rowers, Treadmill ...
#
#                                                  Diet
# 16  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 48  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 52  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 80  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 84  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
#
# HASIL REKOMENDASI FINAL
# Level: Overweight (Goal: Weight Loss) (Age: 18-25)
# Tipe Fitness: Cardio Fitness
# ---------------------------------
# Exercises: Brisk Walking, Outdoor Cycling, Swimming, Running, Cardio Dance, Barbell Back Squat, Goblet Squat, Bench Press, Deadlift, Kettlebell Swing, Lat Pull-Down, Assisted Pull-Up, Plank, Side Plank
# Equipment: Ellipticals Machine, Indoor Rowers, Treadmill machine, Rowing Machine, Barbell, Dumbbell, Flat Bench, Incline Bench, Pull-Up Bar, Yoga Mat, Kettlebell
# Diet: Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagung, Singkong, Ubi); Mineral & Serat: (Bayam, Kangkung, Wortel, Tomat, Brokoli, Jeruk, Apel, Pisang, Pepaya); Protein: (Tahu, Tempe, Kacang-kacangan, Ikan, Ayam Tanpa Kulit, Telur, Daging Tanpa Lemak, Susu Rendah Lemak)

# %%
# Contoh Inference

print("CONTOH 2 (NORMAL)")
get_full_recommendation_test_cosine(sex="Male", age=40, height_cm=170, weight_kg=75, hypertension="No", diabetes="No")
# Out:
# CONTOH 2 (NORMAL)
# 1. Menerima Input Mentah
#    Sex: Male, Age: 40, Height: 170cm, Weight: 75kg
#    Hypertension: No, Diabetes: No
#
# 2. Kalkulasi Turunan
#    Calculated BMI: 25.95
#    Determined Level: Overweight
#    DetermGmbined Fitness Goal: Weight Loss
#    Determined Age Group: 36-45
#
# 3. Prediksi KNN (Fitness Type)
#    Predicted Fitness Type: Cardio Fitness
#
# 4. Rekomendasi Detail (CBF dengan Cosine Sim)
#
#  Mencari filter spesifik...
#    - Mencoba: Age Group, Level, Goal, Sex...
#
# Top 5 item paling mirip (berdasarkan konten):
#                                              Exercises  \
# 592  Brisk Walking, Outdoor Cycling, Swimming, Runn...
# 596  Brisk Walking, Outdoor Cycling, Swimming, Runn...
# 624  Brisk Walking, Outdoor Cycling, Swimming, Runn...
# 656  Brisk Walking, Outdoor Cycling, Swimming, Runn...
# 688  Brisk Walking, Outdoor Cycling, Swimming, Runn...
#
#                                              Equipment  \
# 592  Ellipticals Machine, Indoor Rowers, Treadmill ...
# 596  Ellipticals Machine, Indoor Rowers, Treadmill ...
# 624  Ellipticals Machine, Indoor Rowers, Treadmill ...
# 656  Ellipticals Machine, Indoor Rowers, Treadmill ...
# 688  Ellipticals Machine, Indoor Rowers, Treadmill ...
#
#                                                   Diet
# 592  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 596  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 624  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 656  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 688  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
#
# HASIL REKOMENDASI FINAL
# Level: Overweight (Goal: Weight Loss) (Age: 36-45)
# Tipe Fitness: Cardio Fitness
# ---------------------------------
# Exercises: Brisk Walking, Outdoor Cycling, Swimming, Running, Cardio Dance, Leg Press, Chest Press, Romanian Deadlift, Seated Cable Row, Farmers Walk
# Equipment: Ellipticals Machine, Indoor Rowers, Treadmill machine, Rowing Machine, Leg Press Machine, Dumbbell, Barbell, Smith Machine, Cable Row Machine, Resistance Band
# Diet: Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagung, Singkong, Ubi); Mineral & Serat: (Bayam, Kangkung, Wortel, Tomat, Brokoli, Jeruk, Apel, Pisang, Pepaya); Protein: (Tahu, Tempe, Kacang-kacangan, Ikan, Ayam Tanpa Kulit, Telur, Daging Tanpa Lemak, Susu Rendah Lemak)

# %%
print("CONTOH 3 (OBESE + HYPERTENSION)")
get_full_recommendation_test_cosine(sex="Male", age=45, height_cm=175, weight_kg=100, hypertension="Yes", diabetes="No")
# Out:
# CONTOH 3 (OBESE + HYPERTENSION)
# 1. Menerima Input Mentah
#    Sex: Male, Age: 45, Height: 175cm, Weight: 100kg
#    Hypertension: Yes, Diabetes: No
#
# 2. Kalkulasi Turunan
#    Calculated BMI: 32.65
#    Determined Level: Obese
#    DetermGmbined Fitness Goal: Weight Loss
#    Determined Age Group: 36-45
#
# 3. Prediksi KNN (Fitness Type)
#    Predicted Fitness Type: Cardio Fitness
#
# 4. Rekomendasi Detail (CBF dengan Cosine Sim)
#
#  Mencari filter spesifik...
#    - Mencoba: Age Group, Level, Goal, Sex...
#
# Top 5 item paling mirip (berdasarkan konten):
#                                              Exercises  \
# 601  Brisk Walking, Outdoor Cycling, Swimming, Runn...
# 605  Brisk Walking, Outdoor Cycling, Swimming, Runn...
# 633  Brisk Walking, Outdoor Cycling, Swimming, Runn...
# 637  Brisk Walking, Outdoor Cycling, Swimming, Runn...
# 665  Brisk Walking, Outdoor Cycling, Swimming, Runn...
#
#                                              Equipment  \
# 601  Ellipticals Machine, Indoor Rowers, Treadmill ...
# 605  Ellipticals Machine, Indoor Rowers, Treadmill ...
# 633  Ellipticals Machine, Indoor Rowers, Treadmill ...
# 637  Ellipticals Machine, Indoor Rowers, Treadmill ...
# 665  Ellipticals Machine, Indoor Rowers, Treadmill ...
#
#                                                   Diet
# 601  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 605  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 633  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 637  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
# 665  Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagu...
#
# HASIL REKOMENDASI FINAL
# Level: Obese (Goal: Weight Loss) (Age: 36-45)
# Tipe Fitness: Cardio Fitness
# ---------------------------------
# Exercises: Brisk Walking, Outdoor Cycling, Swimming, Running, Cardio Dance, Elliptical, Stair Climber, Stationary Bike
# Equipment: Ellipticals Machine, Indoor Rowers, Treadmill machine, Rowing Machine
# Diet: Karbohidrat: (Nasi, Kentang, Roti Gandum, Jagung, Singkong, Ubi); Mineral & Serat: (Bayam, Kangkung, Wortel, Tomat, Brokoli, Jeruk, Apel, Pisang, Pepaya); Protein: (Tahu, Tempe, Kacang-kacangan, Ikan, Ayam Tanpa Kulit, Telur, Daging Tanpa Lemak, Susu Rendah Lemak)
